# %%
import os
import gc
import time
import pickle

import pandas as pd
import numpy as np

import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedShuffleSplit
from boostaroota import BoostARoota

# %%
PATH_TO_DATA = ('D:/Py/DataFrames/Santander_Value_Prediction_Challenge(KAGGLE)/')

# %% [markdown]
# ## Reading and joining data

# %%
y = pd.read_csv(os.path.join(PATH_TO_DATA, 'input/train.csv'), usecols=['target'])
y = np.log1p(y.target.values)
print('Target length:', len(y))
# Out:
# Target length: 4459

# %%
# %%time
train_df_statistic = pd.read_csv(os.path.join(PATH_TO_DATA, 'train_with_row_statistic_and_bin_thresh098.csv'))
test_df_statistic = pd.read_csv(os.path.join(PATH_TO_DATA, 'test_with_row_statistic_and_bin_thresh098.csv'))

train_space_reduction = pd.read_csv(os.path.join(PATH_TO_DATA, 'train_space_reduction_thresh098.csv'))
test_space_reduction = pd.read_csv(os.path.join(PATH_TO_DATA, 'test_space_reduction_thresh098.csv'))
# Out:
# Wall time: 1min 34s

# %%
# %%time
train_df = pd.concat([train_df_statistic, train_space_reduction], axis=1)
test_df = pd.concat([test_df_statistic, test_space_reduction], axis=1)

del train_df_statistic, test_df_statistic
del train_space_reduction, test_space_reduction
gc.collect()

print('Train:', train_df.shape)
print('Test:', test_df.shape)
# Out:
# Train: (4459, 4964)
# Test: (49342, 4964)
# Wall time: 4.41 s

# %% [markdown]
# # Boruta Feature Selection

# %%
br = BoostARoota(metric='rmse')
br.fit(train_df, y)
# Out:
# Round:  1  iteration:  1
# Round:  1  iteration:  2
# Round:  1  iteration:  3
# Round:  1  iteration:  4
# Round:  1  iteration:  5
# Round:  1  iteration:  6
# Round:  1  iteration:  7
# Round:  1  iteration:  8
# Round:  1  iteration:  9
# Round:  1  iteration:  10
# Round:  2  iteration:  1
# Round:  2  iteration:  2
# Round:  2  iteration:  3
# Round:  2  iteration:  4
# Round:  2  iteration:  5
# Round:  2  iteration:  6
# Round:  2  iteration:  7
# Round:  2  iteration:  8
# Round:  2  iteration:  9
# Round:  2  iteration:  10
# Round:  3  iteration:  1
# Round:  3  iteration:  2
# Round:  3  iteration:  3
# Round:  3  iteration:  4
# Round:  3  iteration:  5
# Round:  3  iteration:  6
# Round:  3  iteration:  7
# Round:  3  iteration:  8
# Round:  3  iteration:  9
# Round:  3  iteration:  10
# Round:  4  iteration:  1
# Round:  4  iteration:  2
# Round:  4  iteration:  3
# Round:  4  iteration:  4
# Round:  4  iteration:  5
# Round:  4  iteration:  6
# Round:  4  iteration:  7
# Round:  4  iteration:  8
# Round:  4  iteration:  9
# Round:  4  iteration:  10
# BoostARoota ran successfully! Algorithm went through  4  rounds.

# %%
print('Total features:', train_df.shape[1])
print('Number of selected features:', len(br.keep_vars_.values))
# Out:
# Total features: 4964
# Number of selected features: 432

# %%
# оставляем только те фичи, которые Boruta посчитал нужными
boruta_features = br.keep_vars_.values
train_df[boruta_features].to_csv(os.path.join(PATH_TO_DATA, 'train_boruta_stat_bin_red_thresh098.csv'), index=False)
test_df[boruta_features].to_csv(os.path.join(PATH_TO_DATA, 'test_boruta_stat_bin_red_thresh098.csv'), index=False)

# %% [markdown]
# ## CV Folds

# %%
train_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'train_boruta_stat_bin_red_thresh098.csv'))
test_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'test_boruta_stat_bin_red_thresh098.csv'))

# %%
def get_20_cv_splits(data, in_path):
    #stratify_classes = y
    train = pd.read_csv(os.path.join(PATH_TO_DATA, 'input/train.csv'), usecols=['target'])
    stratify_classes =  train.target.apply(lambda x: int(np.log10(x)))
    splits = {}
    for random_state in range(20):
        column = np.zeros(data.shape[0])
        sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=random_state)
        for i, (_, test_index) in enumerate(sss.split(data, stratify_classes)):
            column[test_index] = i

        splits["split{}".format(random_state)] = column

    pd.DataFrame(splits, index=data.index).to_csv(os.path.join(PATH_TO_DATA, in_path))

# %%
# function to generate 100 folds from create_folds_from_cv_splits func
def create_folds_from_cv_splits(in_path, pkl_path):
    
    cv_splits = pd.read_csv(os.path.join(PATH_TO_DATA, in_path))
    folds_list = []
    for ind, i in enumerate(cv_splits.columns[1:]):
        folds = list(set(cv_splits[i].values))
        folds_list.append([])
        for m in folds:
            val_idx = list(cv_splits[cv_splits[i]==m].index)
            train_idx = list(set(list(cv_splits.index)) - set(val_idx))
            folds_list[ind].append((train_idx, val_idx))
    with open(os.path.join(PATH_TO_DATA, pkl_path), 'wb') as f:
        pickle.dump(folds_list, f)
    return folds_list

# %%
LOAD_CV = True

if LOAD_CV:
    with open(os.path.join(PATH_TO_DATA, 'folds/custom_cv_boruta_thresh098.pkl'), 'rb') as f:
        cv_folds = pickle.load(f)
else:
    get_20_cv_splits(train_df, in_path='folds/cv_splits_boruta_stat_bin_red_thresh098.csv')
    cv_folds = create_folds_from_cv_splits(in_path='folds/cv_splits_boruta_stat_bin_red_thresh098.csv',
                                           pkl_path='folds/custom_cv_boruta_thresh098.pkl')

# %% [markdown]
# ## LightGBM

# %%
def run_lgb(train_X, train_y, val_X, val_y, test_X):
    params = {
        "objective" : "regression",
        "metric" : "rmse",
        "num_leaves" : 40,
        'max_depth': 7,
        "learning_rate" : 0.005,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.1,
        "bagging_frequency" : 6,
        "bagging_seed" : 44,
        "verbosity" : -1,
        'num_threads' : 4,
        "seed": 44
    }
    
    start_time = time.time()
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    model = lgb.train(params, lgtrain, 5000, 
                      valid_sets=[lgtrain, lgval], 
                      early_stopping_rounds=100, 
                      verbose_eval=150)
    print('Model training done in {} seconds.'.format(time.time() - start_time))
    
    pred_test_y = np.expm1(model.predict(test_X, num_iteration=model.best_iteration))
    pred_oof_log = model.predict(val_X, num_iteration=model.best_iteration)
    return pred_test_y, pred_oof_log, model

# %%
def run_calculations(X, test, big_cv_folds, func_name = None):
    if not func_name:
        return print('The function to run is not defined')
    else:
        y_oof_20_preds = []
        fold_errors_20_preds =[]
        avg_test_pred_20_preds = []
        fold_errors_std = []
        
        for ind, cv_folds in enumerate(big_cv_folds):
            print('Fitting big fold', ind+1, 'out of', len(big_cv_folds))
            y_oof = np.zeros((y.shape[0]))
            fold_errors =[]
            pred_test_list = []
            
            for i, (train_index, val_index) in enumerate(cv_folds):
                print('Fitting sub fold', i+1, 'out of', len(cv_folds))
                X_train, X_val  = X.iloc[train_index], X.iloc[val_index]
                y_train, y_val = y[train_index], y[val_index]

                # part to include additional functions
                if func_name == 'lgb':
                    pred_test_y, pred_oof_log, clf = run_lgb(X_train, y_train, X_val, y_val, test)
                elif func_name == 'xgb':
                    pred_test_y, pred_oof_log, clf = run_xgb(X_train, y_train, X_val, y_val, test)
                else:
                    return print('The function to run is not correct')

                y_oof[val_index] = pred_oof_log
                curr_fe = np.sqrt(mean_squared_error(y_val, pred_oof_log))
                print(f'Fold error {curr_fe}')
                fold_errors.append(curr_fe)
                pred_test_list.append(list(pred_test_y))

            print('Total error', np.sqrt(mean_squared_error(y, y_oof)))
            total_fe_std = round(np.std(fold_errors), 5)
            print(f'Total std {total_fe_std}')
            avg_test_pred = np.mean(pred_test_list, axis=0)
            
            avg_test_pred_20_preds.append(avg_test_pred)
            fold_errors_20_preds.append(fold_errors)
            y_oof_20_preds.append(y_oof)
            fold_errors_std.append(total_fe_std)
            
        return y_oof_20_preds, avg_test_pred_20_preds, fold_errors_20_preds, fold_errors_std

# %%
# %%time
y_oof_lgb, pred_test_list_lgb, fold_errors, fold_std = run_calculations(train_df, test_df, cv_folds, 'lgb')
# Out:
# Fitting big fold 1 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.37472	valid_1's rmse: 1.47699
# [300]	training's rmse: 1.17894	valid_1's rmse: 1.38463
# [450]	training's rmse: 1.04904	valid_1's rmse: 1.34751
# [600]	training's rmse: 0.953061	valid_1's rmse: 1.33187
# [750]	training's rmse: 0.875047	valid_1's rmse: 1.32576
# [900]	training's rmse: 0.808578	valid_1's rmse: 1.3228
# [1050]	training's rmse: 0.74878	valid_1's rmse: 1.32161
# [1200]	training's rmse: 0.695046	valid_1's rmse: 1.32089
# [1350]	training's rmse: 0.64718	valid_1's rmse: 1.32076
# Early stopping, best iteration is:
# [1255]	training's rmse: 0.676561	valid_1's rmse: 1.32062
# Model training done in 10.193679332733154 seconds.
# Fold error 1.3206234627326736
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40138	valid_1's rmse: 1.44638
# [300]	training's rmse: 1.23042	valid_1's rmse: 1.33666
# [450]	training's rmse: 1.12152	valid_1's rmse: 1.2939
# [600]	training's rmse: 1.04378	valid_1's rmse: 1.27896
# [750]	training's rmse: 0.980899	valid_1's rmse: 1.27135
# [900]	training's rmse: 0.926477	valid_1's rmse: 1.26732
# [1050]	training's rmse: 0.878149	valid_1's rmse: 1.26519
# [1200]	training's rmse: 0.832898	valid_1's rmse: 1.26443
# Early stopping, best iteration is:
# [1123]	training's rmse: 0.85592	valid_1's rmse: 1.26433
# Model training done in 10.228060245513916 seconds.
# Fold error 1.2643297110253742
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39784	valid_1's rmse: 1.46272
# [300]	training's rmse: 1.22389	valid_1's rmse: 1.3675
# [450]	training's rmse: 1.11357	valid_1's rmse: 1.33364
# [600]	training's rmse: 1.03503	valid_1's rmse: 1.32116
# [750]	training's rmse: 0.971109	valid_1's rmse: 1.31493
# [900]	training's rmse: 0.916239	valid_1's rmse: 1.31217
# [1050]	training's rmse: 0.866918	valid_1's rmse: 1.3106
# [1200]	training's rmse: 0.820356	valid_1's rmse: 1.3094
# Early stopping, best iteration is:
# [1249]	training's rmse: 0.805767	valid_1's rmse: 1.30902
# Model training done in 11.429309368133545 seconds.
# Fold error 1.3090195964186326
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38668	valid_1's rmse: 1.52375
# [300]	training's rmse: 1.21113	valid_1's rmse: 1.43088
# [450]	training's rmse: 1.09919	valid_1's rmse: 1.39537
# [600]	training's rmse: 1.01835	valid_1's rmse: 1.37803
# [750]	training's rmse: 0.953491	valid_1's rmse: 1.37033
# [900]	training's rmse: 0.897033	valid_1's rmse: 1.36539
# [1050]	training's rmse: 0.847206	valid_1's rmse: 1.3622
# [1200]	training's rmse: 0.801377	valid_1's rmse: 1.35932
# [1350]	training's rmse: 0.759773	valid_1's rmse: 1.35696
# [1500]	training's rmse: 0.721159	valid_1's rmse: 1.35553
# [1650]	training's rmse: 0.684189	valid_1's rmse: 1.35313
# [1800]	training's rmse: 0.649759	valid_1's rmse: 1.35179
# [1950]	training's rmse: 0.617896	valid_1's rmse: 1.35066
# [2100]	training's rmse: 0.586731	valid_1's rmse: 1.34956
# [2250]	training's rmse: 0.557385	valid_1's rmse: 1.34898
# [2400]	training's rmse: 0.531162	valid_1's rmse: 1.34835
# [2550]	training's rmse: 0.506565	valid_1's rmse: 1.34756
# [2700]	training's rmse: 0.48162	valid_1's rmse: 1.34709
# [2850]	training's rmse: 0.459475	valid_1's rmse: 1.34682
# Early stopping, best iteration is:
# [2785]	training's rmse: 0.468716	valid_1's rmse: 1.34677
# Model training done in 23.165642738342285 seconds.
# Fold error 1.3467692486785137
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38907	valid_1's rmse: 1.48411
# [300]	training's rmse: 1.20758	valid_1's rmse: 1.40064
# [450]	training's rmse: 1.09157	valid_1's rmse: 1.36706
# [600]	training's rmse: 1.00859	valid_1's rmse: 1.35412
# [750]	training's rmse: 0.940505	valid_1's rmse: 1.34825
# [900]	training's rmse: 0.881318	valid_1's rmse: 1.34448
# [1050]	training's rmse: 0.82852	valid_1's rmse: 1.3424
# [1200]	training's rmse: 0.780247	valid_1's rmse: 1.34199
# [1350]	training's rmse: 0.734413	valid_1's rmse: 1.34208
# Early stopping, best iteration is:
# [1302]	training's rmse: 0.748794	valid_1's rmse: 1.34181
# Model training done in 11.841484785079956 seconds.
# Fold error 1.341806746946645
# Total error 1.32203955367
# Total std 0.0295
# Fitting big fold 2 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.35812	valid_1's rmse: 1.49942
# [300]	training's rmse: 1.15676	valid_1's rmse: 1.41863
# [450]	training's rmse: 1.02764	valid_1's rmse: 1.38788
# [600]	training's rmse: 0.932713	valid_1's rmse: 1.37602
# [750]	training's rmse: 0.855567	valid_1's rmse: 1.37122
# [900]	training's rmse: 0.790175	valid_1's rmse: 1.36854
# [1050]	training's rmse: 0.731321	valid_1's rmse: 1.36649
# [1200]	training's rmse: 0.678693	valid_1's rmse: 1.36583
# [1350]	training's rmse: 0.629781	valid_1's rmse: 1.3659
# Early stopping, best iteration is:
# [1281]	training's rmse: 0.651752	valid_1's rmse: 1.36566
# Model training done in 10.45169448852539 seconds.
# Fold error 1.3656618656558586
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40285	valid_1's rmse: 1.43827
# [300]	training's rmse: 1.23133	valid_1's rmse: 1.33485
# [450]	training's rmse: 1.12146	valid_1's rmse: 1.29038
# [600]	training's rmse: 1.04296	valid_1's rmse: 1.27495
# [750]	training's rmse: 0.979863	valid_1's rmse: 1.26755
# [900]	training's rmse: 0.92356	valid_1's rmse: 1.26213
# [1050]	training's rmse: 0.874444	valid_1's rmse: 1.25914
# [1200]	training's rmse: 0.829161	valid_1's rmse: 1.25668
# [1350]	training's rmse: 0.788053	valid_1's rmse: 1.25638
# Early stopping, best iteration is:
# [1334]	training's rmse: 0.792629	valid_1's rmse: 1.25595
# Model training done in 12.052777767181396 seconds.
# Fold error 1.255953999932664
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40088	valid_1's rmse: 1.45433
# [300]	training's rmse: 1.22895	valid_1's rmse: 1.34691
# [450]	training's rmse: 1.1189	valid_1's rmse: 1.30016
# [600]	training's rmse: 1.03874	valid_1's rmse: 1.28137
# [750]	training's rmse: 0.973892	valid_1's rmse: 1.27147
# [900]	training's rmse: 0.916632	valid_1's rmse: 1.26614
# [1050]	training's rmse: 0.86689	valid_1's rmse: 1.26241
# [1200]	training's rmse: 0.819234	valid_1's rmse: 1.26056
# [1350]	training's rmse: 0.776524	valid_1's rmse: 1.25885
# [1500]	training's rmse: 0.73612	valid_1's rmse: 1.25861
# Early stopping, best iteration is:
# [1454]	training's rmse: 0.747771	valid_1's rmse: 1.25799
# Model training done in 13.11372447013855 seconds.
# Fold error 1.2579852343866202
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38995	valid_1's rmse: 1.50989
# [300]	training's rmse: 1.21428	valid_1's rmse: 1.41282
# [450]	training's rmse: 1.10165	valid_1's rmse: 1.37553
# [600]	training's rmse: 1.02036	valid_1's rmse: 1.3618
# [750]	training's rmse: 0.954826	valid_1's rmse: 1.35549
# [900]	training's rmse: 0.898376	valid_1's rmse: 1.35049
# [1050]	training's rmse: 0.84776	valid_1's rmse: 1.3498
# Early stopping, best iteration is:
# [992]	training's rmse: 0.866853	valid_1's rmse: 1.34961
# Model training done in 9.798463821411133 seconds.
# Fold error 1.349612226429141
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3936	valid_1's rmse: 1.454
# [300]	training's rmse: 1.2137	valid_1's rmse: 1.3605
# [450]	training's rmse: 1.09939	valid_1's rmse: 1.32788
# [600]	training's rmse: 1.01773	valid_1's rmse: 1.31592
# [750]	training's rmse: 0.951495	valid_1's rmse: 1.30961
# [900]	training's rmse: 0.895228	valid_1's rmse: 1.30527
# [1050]	training's rmse: 0.84547	valid_1's rmse: 1.30289
# [1200]	training's rmse: 0.799582	valid_1's rmse: 1.30153
# [1350]	training's rmse: 0.756497	valid_1's rmse: 1.29961
# [1500]	training's rmse: 0.716376	valid_1's rmse: 1.29867
# [1650]	training's rmse: 0.679183	valid_1's rmse: 1.29819
# [1800]	training's rmse: 0.644161	valid_1's rmse: 1.29759
# [1950]	training's rmse: 0.610199	valid_1's rmse: 1.29718
# [2100]	training's rmse: 0.578548	valid_1's rmse: 1.29703
# Early stopping, best iteration is:
# [2028]	training's rmse: 0.593222	valid_1's rmse: 1.29674
# Model training done in 16.222151041030884 seconds.
# Fold error 1.2967371405923904
# Total error 1.32502507405
# Total std 0.04551
# Fitting big fold 3 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.36394	valid_1's rmse: 1.49644
# [300]	training's rmse: 1.16086	valid_1's rmse: 1.41387
# [450]	training's rmse: 1.0272	valid_1's rmse: 1.38208
# [600]	training's rmse: 0.932213	valid_1's rmse: 1.3701
# [750]	training's rmse: 0.853153	valid_1's rmse: 1.36517
# [900]	training's rmse: 0.788723	valid_1's rmse: 1.36267
# [1050]	training's rmse: 0.731264	valid_1's rmse: 1.36218
# Early stopping, best iteration is:
# [967]	training's rmse: 0.762589	valid_1's rmse: 1.36199
# Model training done in 7.893824815750122 seconds.
# Fold error 1.361986976918688
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40061	valid_1's rmse: 1.45562
# [300]	training's rmse: 1.22769	valid_1's rmse: 1.35989
# [450]	training's rmse: 1.11751	valid_1's rmse: 1.32322
# [600]	training's rmse: 1.03927	valid_1's rmse: 1.30739
# [750]	training's rmse: 0.975506	valid_1's rmse: 1.29989
# [900]	training's rmse: 0.920162	valid_1's rmse: 1.2955
# [1050]	training's rmse: 0.871263	valid_1's rmse: 1.29293
# [1200]	training's rmse: 0.825985	valid_1's rmse: 1.29121
# [1350]	training's rmse: 0.78404	valid_1's rmse: 1.28846
# [1500]	training's rmse: 0.744607	valid_1's rmse: 1.28738
# Early stopping, best iteration is:
# [1485]	training's rmse: 0.748311	valid_1's rmse: 1.2872
# Model training done in 13.67221713066101 seconds.
# Fold error 1.2872046466037965
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39797	valid_1's rmse: 1.46157
# [300]	training's rmse: 1.22308	valid_1's rmse: 1.37234
# [450]	training's rmse: 1.11178	valid_1's rmse: 1.34177
# [600]	training's rmse: 1.03126	valid_1's rmse: 1.3322
# [750]	training's rmse: 0.967139	valid_1's rmse: 1.32838
# [900]	training's rmse: 0.911622	valid_1's rmse: 1.32725
# [1050]	training's rmse: 0.860401	valid_1's rmse: 1.32595
# Early stopping, best iteration is:
# [1053]	training's rmse: 0.859462	valid_1's rmse: 1.3259
# Model training done in 9.863439321517944 seconds.
# Fold error 1.3259035828345302
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39115	valid_1's rmse: 1.50389
# [300]	training's rmse: 1.21723	valid_1's rmse: 1.40385
# [450]	training's rmse: 1.10682	valid_1's rmse: 1.36214
# [600]	training's rmse: 1.02695	valid_1's rmse: 1.34475
# [750]	training's rmse: 0.962656	valid_1's rmse: 1.3364
# [900]	training's rmse: 0.906578	valid_1's rmse: 1.33144
# [1050]	training's rmse: 0.856547	valid_1's rmse: 1.32837
# [1200]	training's rmse: 0.809496	valid_1's rmse: 1.32615
# [1350]	training's rmse: 0.767484	valid_1's rmse: 1.32476
# [1500]	training's rmse: 0.727304	valid_1's rmse: 1.32407
# [1650]	training's rmse: 0.688372	valid_1's rmse: 1.32383
# Early stopping, best iteration is:
# [1585]	training's rmse: 0.705462	valid_1's rmse: 1.32351
# Model training done in 13.803656816482544 seconds.
# Fold error 1.3235135252439227
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3932	valid_1's rmse: 1.47218
# [300]	training's rmse: 1.21533	valid_1's rmse: 1.37692
# [450]	training's rmse: 1.10012	valid_1's rmse: 1.34095
# [600]	training's rmse: 1.01762	valid_1's rmse: 1.32663
# [750]	training's rmse: 0.950194	valid_1's rmse: 1.31978
# [900]	training's rmse: 0.891585	valid_1's rmse: 1.31464
# [1050]	training's rmse: 0.839332	valid_1's rmse: 1.31276
# [1200]	training's rmse: 0.791093	valid_1's rmse: 1.31182
# [1350]	training's rmse: 0.745517	valid_1's rmse: 1.31071
# [1500]	training's rmse: 0.703373	valid_1's rmse: 1.31075
# Early stopping, best iteration is:
# [1414]	training's rmse: 0.727179	valid_1's rmse: 1.31056
# Model training done in 12.180252075195312 seconds.
# Fold error 1.3105642970728766
# Total error 1.33373822774
# Total std 0.02432
# Fitting big fold 4 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.37324	valid_1's rmse: 1.47773
# [300]	training's rmse: 1.17328	valid_1's rmse: 1.38593
# [450]	training's rmse: 1.04067	valid_1's rmse: 1.3522
# [600]	training's rmse: 0.944278	valid_1's rmse: 1.33932
# [750]	training's rmse: 0.867198	valid_1's rmse: 1.3345
# [900]	training's rmse: 0.801991	valid_1's rmse: 1.33166
# [1050]	training's rmse: 0.745247	valid_1's rmse: 1.3306
# [1200]	training's rmse: 0.690289	valid_1's rmse: 1.33038
# Early stopping, best iteration is:
# [1249]	training's rmse: 0.673517	valid_1's rmse: 1.33014
# Model training done in 9.799951791763306 seconds.
# Fold error 1.3301436148874748
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39923	valid_1's rmse: 1.47074
# [300]	training's rmse: 1.22692	valid_1's rmse: 1.38561
# [450]	training's rmse: 1.11778	valid_1's rmse: 1.35657
# [600]	training's rmse: 1.03858	valid_1's rmse: 1.34708
# [750]	training's rmse: 0.974148	valid_1's rmse: 1.34169
# [900]	training's rmse: 0.917727	valid_1's rmse: 1.34053
# [1050]	training's rmse: 0.868117	valid_1's rmse: 1.33973
# [1200]	training's rmse: 0.821372	valid_1's rmse: 1.3378
# Early stopping, best iteration is:
# [1226]	training's rmse: 0.813918	valid_1's rmse: 1.33762
# Model training done in 12.504139184951782 seconds.
# Fold error 1.3376207676628653
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39304	valid_1's rmse: 1.49669
# [300]	training's rmse: 1.21858	valid_1's rmse: 1.40768
# [450]	training's rmse: 1.10709	valid_1's rmse: 1.37291
# [600]	training's rmse: 1.02742	valid_1's rmse: 1.36095
# [750]	training's rmse: 0.964082	valid_1's rmse: 1.35513
# [900]	training's rmse: 0.908577	valid_1's rmse: 1.35268
# [1050]	training's rmse: 0.860426	valid_1's rmse: 1.35189
# Early stopping, best iteration is:
# [988]	training's rmse: 0.880351	valid_1's rmse: 1.35166
# Model training done in 9.503342390060425 seconds.
# Fold error 1.3516569908917033
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39209	valid_1's rmse: 1.49529
# [300]	training's rmse: 1.21725	valid_1's rmse: 1.40249
# [450]	training's rmse: 1.10541	valid_1's rmse: 1.3628
# [600]	training's rmse: 1.02454	valid_1's rmse: 1.34628
# [750]	training's rmse: 0.960645	valid_1's rmse: 1.33733
# [900]	training's rmse: 0.905056	valid_1's rmse: 1.33231
# [1050]	training's rmse: 0.855665	valid_1's rmse: 1.32923
# [1200]	training's rmse: 0.811338	valid_1's rmse: 1.32797
# [1350]	training's rmse: 0.770308	valid_1's rmse: 1.32615
# [1500]	training's rmse: 0.731935	valid_1's rmse: 1.32468
# [1650]	training's rmse: 0.695571	valid_1's rmse: 1.3234
# [1800]	training's rmse: 0.662065	valid_1's rmse: 1.32177
# [1950]	training's rmse: 0.62931	valid_1's rmse: 1.32128
# [2100]	training's rmse: 0.597251	valid_1's rmse: 1.32065
# [2250]	training's rmse: 0.567594	valid_1's rmse: 1.31905
# [2400]	training's rmse: 0.539451	valid_1's rmse: 1.31856
# [2550]	training's rmse: 0.514184	valid_1's rmse: 1.31788
# [2700]	training's rmse: 0.489399	valid_1's rmse: 1.31733
# [2850]	training's rmse: 0.466821	valid_1's rmse: 1.3169
# [3000]	training's rmse: 0.445756	valid_1's rmse: 1.31654
# [3150]	training's rmse: 0.425306	valid_1's rmse: 1.3161
# Early stopping, best iteration is:
# [3066]	training's rmse: 0.436463	valid_1's rmse: 1.31604
# Model training done in 24.89568829536438 seconds.
# Fold error 1.316043506752395
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39132	valid_1's rmse: 1.4828
# [300]	training's rmse: 1.21308	valid_1's rmse: 1.38769
# [450]	training's rmse: 1.09974	valid_1's rmse: 1.34933
# [600]	training's rmse: 1.01812	valid_1's rmse: 1.33387
# [750]	training's rmse: 0.952389	valid_1's rmse: 1.32749
# [900]	training's rmse: 0.895675	valid_1's rmse: 1.32328
# [1050]	training's rmse: 0.844646	valid_1's rmse: 1.32106
# [1200]	training's rmse: 0.799174	valid_1's rmse: 1.31923
# [1350]	training's rmse: 0.755855	valid_1's rmse: 1.31763
# [1500]	training's rmse: 0.715586	valid_1's rmse: 1.31638
# [1650]	training's rmse: 0.678012	valid_1's rmse: 1.31518
# [1800]	training's rmse: 0.641956	valid_1's rmse: 1.31486
# Early stopping, best iteration is:
# [1837]	training's rmse: 0.633652	valid_1's rmse: 1.31427
# Model training done in 15.42061448097229 seconds.
# Fold error 1.314266652098182
# Total error 1.32831933978
# Total std 0.01392
# Fitting big fold 5 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.36632	valid_1's rmse: 1.49801
# [300]	training's rmse: 1.16968	valid_1's rmse: 1.40437
# [450]	training's rmse: 1.04072	valid_1's rmse: 1.36716
# [600]	training's rmse: 0.947167	valid_1's rmse: 1.35323
# [750]	training's rmse: 0.866865	valid_1's rmse: 1.34637
# [900]	training's rmse: 0.800328	valid_1's rmse: 1.34276
# [1050]	training's rmse: 0.738956	valid_1's rmse: 1.33993
# [1200]	training's rmse: 0.683549	valid_1's rmse: 1.33892
# [1350]	training's rmse: 0.634566	valid_1's rmse: 1.3389
# Early stopping, best iteration is:
# [1270]	training's rmse: 0.659604	valid_1's rmse: 1.33864
# Model training done in 10.196764469146729 seconds.
# Fold error 1.3386432533420562
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39774	valid_1's rmse: 1.47664
# [300]	training's rmse: 1.22608	valid_1's rmse: 1.39161
# [450]	training's rmse: 1.11719	valid_1's rmse: 1.35773
# [600]	training's rmse: 1.03953	valid_1's rmse: 1.34534
# [750]	training's rmse: 0.976552	valid_1's rmse: 1.33783
# [900]	training's rmse: 0.922997	valid_1's rmse: 1.33319
# [1050]	training's rmse: 0.875132	valid_1's rmse: 1.32953
# [1200]	training's rmse: 0.831805	valid_1's rmse: 1.32873
# [1350]	training's rmse: 0.790764	valid_1's rmse: 1.32726
# [1500]	training's rmse: 0.75173	valid_1's rmse: 1.32686
# [1650]	training's rmse: 0.71575	valid_1's rmse: 1.32638
# [1800]	training's rmse: 0.681294	valid_1's rmse: 1.32591
# Early stopping, best iteration is:
# [1748]	training's rmse: 0.692539	valid_1's rmse: 1.32552
# Model training done in 15.872966051101685 seconds.
# Fold error 1.3255170125968476
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39528	valid_1's rmse: 1.48403
# [300]	training's rmse: 1.222	valid_1's rmse: 1.38264
# [450]	training's rmse: 1.11325	valid_1's rmse: 1.34152
# [600]	training's rmse: 1.03474	valid_1's rmse: 1.32404
# [750]	training's rmse: 0.971969	valid_1's rmse: 1.31481
# [900]	training's rmse: 0.917755	valid_1's rmse: 1.30961
# [1050]	training's rmse: 0.869337	valid_1's rmse: 1.30673
# [1200]	training's rmse: 0.823817	valid_1's rmse: 1.30694
# Early stopping, best iteration is:
# [1115]	training's rmse: 0.84953	valid_1's rmse: 1.30626
# Model training done in 10.956125974655151 seconds.
# Fold error 1.306259697093477
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39739	valid_1's rmse: 1.45105
# [300]	training's rmse: 1.2193	valid_1's rmse: 1.36304
# [450]	training's rmse: 1.10586	valid_1's rmse: 1.32919
# [600]	training's rmse: 1.02492	valid_1's rmse: 1.31773
# [750]	training's rmse: 0.958651	valid_1's rmse: 1.31268
# [900]	training's rmse: 0.905125	valid_1's rmse: 1.31028
# [1050]	training's rmse: 0.855952	valid_1's rmse: 1.30926
# [1200]	training's rmse: 0.808802	valid_1's rmse: 1.30885
# [1350]	training's rmse: 0.764646	valid_1's rmse: 1.30889
# Early stopping, best iteration is:
# [1250]	training's rmse: 0.793475	valid_1's rmse: 1.30846
# Model training done in 11.092525243759155 seconds.
# Fold error 1.3084618582198062
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.391	valid_1's rmse: 1.4784
# [300]	training's rmse: 1.21225	valid_1's rmse: 1.38808
# [450]	training's rmse: 1.09771	valid_1's rmse: 1.35223
# [600]	training's rmse: 1.01356	valid_1's rmse: 1.33818
# [750]	training's rmse: 0.946218	valid_1's rmse: 1.33065
# [900]	training's rmse: 0.887502	valid_1's rmse: 1.32632
# [1050]	training's rmse: 0.834903	valid_1's rmse: 1.32313
# [1200]	training's rmse: 0.786498	valid_1's rmse: 1.32214
# [1350]	training's rmse: 0.741305	valid_1's rmse: 1.32067
# [1500]	training's rmse: 0.700357	valid_1's rmse: 1.31965
# [1650]	training's rmse: 0.661668	valid_1's rmse: 1.31919
# [1800]	training's rmse: 0.624914	valid_1's rmse: 1.31856
# Early stopping, best iteration is:
# [1811]	training's rmse: 0.622329	valid_1's rmse: 1.31847
# Model training done in 15.921077966690063 seconds.
# Fold error 1.318468018003328
# Total error 1.32439511512
# Total std 0.01184
# Fitting big fold 6 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3687	valid_1's rmse: 1.4787
# [300]	training's rmse: 1.16896	valid_1's rmse: 1.38945
# [450]	training's rmse: 1.03713	valid_1's rmse: 1.35527
# [600]	training's rmse: 0.941582	valid_1's rmse: 1.34225
# [750]	training's rmse: 0.865779	valid_1's rmse: 1.33621
# [900]	training's rmse: 0.800189	valid_1's rmse: 1.33302
# [1050]	training's rmse: 0.745133	valid_1's rmse: 1.3309
# [1200]	training's rmse: 0.692915	valid_1's rmse: 1.32927
# [1350]	training's rmse: 0.646569	valid_1's rmse: 1.329
# Early stopping, best iteration is:
# [1375]	training's rmse: 0.638737	valid_1's rmse: 1.32889
# Model training done in 10.55337643623352 seconds.
# Fold error 1.3288898496048824
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39931	valid_1's rmse: 1.49438
# [300]	training's rmse: 1.22848	valid_1's rmse: 1.37959
# [450]	training's rmse: 1.11971	valid_1's rmse: 1.32998
# [600]	training's rmse: 1.04192	valid_1's rmse: 1.31028
# [750]	training's rmse: 0.97811	valid_1's rmse: 1.29944
# [900]	training's rmse: 0.922657	valid_1's rmse: 1.29287
# [1050]	training's rmse: 0.872715	valid_1's rmse: 1.28979
# Early stopping, best iteration is:
# [1015]	training's rmse: 0.884431	valid_1's rmse: 1.2895
# Model training done in 9.577742099761963 seconds.
# Fold error 1.2894952121302907
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39872	valid_1's rmse: 1.46341
# [300]	training's rmse: 1.22546	valid_1's rmse: 1.36744
# [450]	training's rmse: 1.11521	valid_1's rmse: 1.32848
# [600]	training's rmse: 1.03536	valid_1's rmse: 1.31331
# [750]	training's rmse: 0.970473	valid_1's rmse: 1.30402
# [900]	training's rmse: 0.913477	valid_1's rmse: 1.29798
# [1050]	training's rmse: 0.862859	valid_1's rmse: 1.29482
# [1200]	training's rmse: 0.816219	valid_1's rmse: 1.29229
# [1350]	training's rmse: 0.774036	valid_1's rmse: 1.29034
# [1500]	training's rmse: 0.734391	valid_1's rmse: 1.2892
# Early stopping, best iteration is:
# [1497]	training's rmse: 0.735266	valid_1's rmse: 1.28903
# Model training done in 13.467865705490112 seconds.
# Fold error 1.289033187240554
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39346	valid_1's rmse: 1.47559
# [300]	training's rmse: 1.21653	valid_1's rmse: 1.3939
# [450]	training's rmse: 1.10419	valid_1's rmse: 1.36368
# [600]	training's rmse: 1.02309	valid_1's rmse: 1.35383
# [750]	training's rmse: 0.958258	valid_1's rmse: 1.34704
# [900]	training's rmse: 0.901114	valid_1's rmse: 1.34487
# [1050]	training's rmse: 0.852833	valid_1's rmse: 1.34353
# [1200]	training's rmse: 0.806282	valid_1's rmse: 1.34302
# Early stopping, best iteration is:
# [1157]	training's rmse: 0.819215	valid_1's rmse: 1.34253
# Model training done in 10.53750228881836 seconds.
# Fold error 1.3425285051157
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38854	valid_1's rmse: 1.49278
# [300]	training's rmse: 1.2093	valid_1's rmse: 1.40342
# [450]	training's rmse: 1.09433	valid_1's rmse: 1.36782
# [600]	training's rmse: 1.01262	valid_1's rmse: 1.35336
# [750]	training's rmse: 0.945753	valid_1's rmse: 1.34517
# [900]	training's rmse: 0.889608	valid_1's rmse: 1.34053
# [1050]	training's rmse: 0.838482	valid_1's rmse: 1.33882
# [1200]	training's rmse: 0.790615	valid_1's rmse: 1.33667
# [1350]	training's rmse: 0.744732	valid_1's rmse: 1.33559
# [1500]	training's rmse: 0.703796	valid_1's rmse: 1.33402
# Early stopping, best iteration is:
# [1503]	training's rmse: 0.702919	valid_1's rmse: 1.33396
# Model training done in 13.00113034248352 seconds.
# Fold error 1.3339623741708542
# Total error 1.32320411281
# Total std 0.02289
# Fitting big fold 7 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38073	valid_1's rmse: 1.45949
# [300]	training's rmse: 1.18229	valid_1's rmse: 1.37075
# [450]	training's rmse: 1.05124	valid_1's rmse: 1.33601
# [600]	training's rmse: 0.955303	valid_1's rmse: 1.32278
# [750]	training's rmse: 0.880417	valid_1's rmse: 1.31686
# [900]	training's rmse: 0.817568	valid_1's rmse: 1.31397
# [1050]	training's rmse: 0.760645	valid_1's rmse: 1.31279
# [1200]	training's rmse: 0.707098	valid_1's rmse: 1.31231
# Early stopping, best iteration is:
# [1164]	training's rmse: 0.719649	valid_1's rmse: 1.31198
# Model training done in 9.08918285369873 seconds.
# Fold error 1.3119814283099858
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39552	valid_1's rmse: 1.5027
# [300]	training's rmse: 1.22289	valid_1's rmse: 1.41522
# [450]	training's rmse: 1.11277	valid_1's rmse: 1.38274
# [600]	training's rmse: 1.03413	valid_1's rmse: 1.37086
# [750]	training's rmse: 0.971924	valid_1's rmse: 1.36593
# [900]	training's rmse: 0.917695	valid_1's rmse: 1.3634
# [1050]	training's rmse: 0.868418	valid_1's rmse: 1.36184
# [1200]	training's rmse: 0.824117	valid_1's rmse: 1.36061
# [1350]	training's rmse: 0.781188	valid_1's rmse: 1.36112
# Early stopping, best iteration is:
# [1296]	training's rmse: 0.796636	valid_1's rmse: 1.36012
# Model training done in 11.954572439193726 seconds.
# Fold error 1.3601228486946129
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38983	valid_1's rmse: 1.5232
# [300]	training's rmse: 1.2164	valid_1's rmse: 1.42726
# [450]	training's rmse: 1.10613	valid_1's rmse: 1.38796
# [600]	training's rmse: 1.02682	valid_1's rmse: 1.37557
# [750]	training's rmse: 0.962299	valid_1's rmse: 1.37117
# [900]	training's rmse: 0.906091	valid_1's rmse: 1.36924
# [1050]	training's rmse: 0.85701	valid_1's rmse: 1.36742
# Early stopping, best iteration is:
# [1011]	training's rmse: 0.869416	valid_1's rmse: 1.36723
# Model training done in 9.619405746459961 seconds.
# Fold error 1.3672261154938168
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39085	valid_1's rmse: 1.50621
# [300]	training's rmse: 1.21589	valid_1's rmse: 1.40699
# [450]	training's rmse: 1.10455	valid_1's rmse: 1.36562
# [600]	training's rmse: 1.02405	valid_1's rmse: 1.34811
# [750]	training's rmse: 0.959953	valid_1's rmse: 1.33984
# [900]	training's rmse: 0.90323	valid_1's rmse: 1.33489
# [1050]	training's rmse: 0.854253	valid_1's rmse: 1.33185
# [1200]	training's rmse: 0.807827	valid_1's rmse: 1.3302
# [1350]	training's rmse: 0.765181	valid_1's rmse: 1.32893
# [1500]	training's rmse: 0.725043	valid_1's rmse: 1.32781
# [1650]	training's rmse: 0.686461	valid_1's rmse: 1.32734
# [1800]	training's rmse: 0.65192	valid_1's rmse: 1.3273
# Early stopping, best iteration is:
# [1711]	training's rmse: 0.672307	valid_1's rmse: 1.32692
# Model training done in 14.719766616821289 seconds.
# Fold error 1.3269182194437237
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39463	valid_1's rmse: 1.46677
# [300]	training's rmse: 1.21605	valid_1's rmse: 1.37126
# [450]	training's rmse: 1.10158	valid_1's rmse: 1.33365
# [600]	training's rmse: 1.01953	valid_1's rmse: 1.32068
# [750]	training's rmse: 0.952854	valid_1's rmse: 1.31373
# [900]	training's rmse: 0.894704	valid_1's rmse: 1.30913
# [1050]	training's rmse: 0.843351	valid_1's rmse: 1.30663
# [1200]	training's rmse: 0.795808	valid_1's rmse: 1.30489
# [1350]	training's rmse: 0.752728	valid_1's rmse: 1.30328
# [1500]	training's rmse: 0.712117	valid_1's rmse: 1.302
# [1650]	training's rmse: 0.672754	valid_1's rmse: 1.30163
# [1800]	training's rmse: 0.636031	valid_1's rmse: 1.30107
# [1950]	training's rmse: 0.602321	valid_1's rmse: 1.30075
# Early stopping, best iteration is:
# [1949]	training's rmse: 0.602618	valid_1's rmse: 1.30072
# Model training done in 16.115508317947388 seconds.
# Fold error 1.3007170909270651
# Total error 1.32462330169
# Total std 0.02618
# Fitting big fold 8 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.37449	valid_1's rmse: 1.47933
# [300]	training's rmse: 1.17666	valid_1's rmse: 1.38691
# [450]	training's rmse: 1.04394	valid_1's rmse: 1.34938
# [600]	training's rmse: 0.949209	valid_1's rmse: 1.33537
# [750]	training's rmse: 0.870982	valid_1's rmse: 1.32924
# [900]	training's rmse: 0.804681	valid_1's rmse: 1.3255
# [1050]	training's rmse: 0.746022	valid_1's rmse: 1.32354
# [1200]	training's rmse: 0.692408	valid_1's rmse: 1.32239
# [1350]	training's rmse: 0.643486	valid_1's rmse: 1.32152
# [1500]	training's rmse: 0.597179	valid_1's rmse: 1.32048
# [1650]	training's rmse: 0.554469	valid_1's rmse: 1.32027
# [1800]	training's rmse: 0.515377	valid_1's rmse: 1.3203
# Early stopping, best iteration is:
# [1743]	training's rmse: 0.529599	valid_1's rmse: 1.32011
# Model training done in 13.139513969421387 seconds.
# Fold error 1.3201052769943846
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40048	valid_1's rmse: 1.46092
# [300]	training's rmse: 1.22861	valid_1's rmse: 1.36754
# [450]	training's rmse: 1.1197	valid_1's rmse: 1.33018
# [600]	training's rmse: 1.04142	valid_1's rmse: 1.31712
# [750]	training's rmse: 0.978099	valid_1's rmse: 1.31165
# [900]	training's rmse: 0.92177	valid_1's rmse: 1.30713
# [1050]	training's rmse: 0.873087	valid_1's rmse: 1.30467
# [1200]	training's rmse: 0.827415	valid_1's rmse: 1.30345
# Early stopping, best iteration is:
# [1238]	training's rmse: 0.816389	valid_1's rmse: 1.30254
# Model training done in 11.79833436012268 seconds.
# Fold error 1.3025415793839679
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39104	valid_1's rmse: 1.50935
# [300]	training's rmse: 1.2157	valid_1's rmse: 1.42792
# [450]	training's rmse: 1.10377	valid_1's rmse: 1.40202
# [600]	training's rmse: 1.02477	valid_1's rmse: 1.39296
# [750]	training's rmse: 0.960987	valid_1's rmse: 1.3903
# [900]	training's rmse: 0.906528	valid_1's rmse: 1.38991
# Early stopping, best iteration is:
# [858]	training's rmse: 0.92134	valid_1's rmse: 1.38925
# Model training done in 8.387346506118774 seconds.
# Fold error 1.389251734952783
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3929	valid_1's rmse: 1.48461
# [300]	training's rmse: 1.21842	valid_1's rmse: 1.38997
# [450]	training's rmse: 1.1065	valid_1's rmse: 1.34826
# [600]	training's rmse: 1.02496	valid_1's rmse: 1.33215
# [750]	training's rmse: 0.960147	valid_1's rmse: 1.3228
# [900]	training's rmse: 0.905057	valid_1's rmse: 1.31762
# [1050]	training's rmse: 0.854794	valid_1's rmse: 1.31515
# [1200]	training's rmse: 0.80779	valid_1's rmse: 1.31368
# [1350]	training's rmse: 0.766155	valid_1's rmse: 1.31201
# [1500]	training's rmse: 0.726746	valid_1's rmse: 1.31178
# Early stopping, best iteration is:
# [1442]	training's rmse: 0.741764	valid_1's rmse: 1.31145
# Model training done in 12.63062071800232 seconds.
# Fold error 1.3114517596116917
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39033	valid_1's rmse: 1.48342
# [300]	training's rmse: 1.2116	valid_1's rmse: 1.38905
# [450]	training's rmse: 1.09796	valid_1's rmse: 1.35113
# [600]	training's rmse: 1.01715	valid_1's rmse: 1.33752
# [750]	training's rmse: 0.949358	valid_1's rmse: 1.33067
# [900]	training's rmse: 0.891351	valid_1's rmse: 1.3259
# [1050]	training's rmse: 0.838725	valid_1's rmse: 1.32359
# [1200]	training's rmse: 0.790371	valid_1's rmse: 1.32152
# [1350]	training's rmse: 0.745058	valid_1's rmse: 1.31995
# Early stopping, best iteration is:
# [1388]	training's rmse: 0.734445	valid_1's rmse: 1.31939
# Model training done in 12.600363492965698 seconds.
# Fold error 1.319392712581676
# Total error 1.3257203964
# Total std 0.03101
# Fitting big fold 9 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3698	valid_1's rmse: 1.49778
# [300]	training's rmse: 1.17892	valid_1's rmse: 1.40172
# [450]	training's rmse: 1.0521	valid_1's rmse: 1.36125
# [600]	training's rmse: 0.957129	valid_1's rmse: 1.3439
# [750]	training's rmse: 0.878516	valid_1's rmse: 1.33489
# [900]	training's rmse: 0.810655	valid_1's rmse: 1.32988
# [1050]	training's rmse: 0.752135	valid_1's rmse: 1.32692
# [1200]	training's rmse: 0.700266	valid_1's rmse: 1.32486
# [1350]	training's rmse: 0.651522	valid_1's rmse: 1.32351
# [1500]	training's rmse: 0.60758	valid_1's rmse: 1.3227
# [1650]	training's rmse: 0.565435	valid_1's rmse: 1.32204
# [1800]	training's rmse: 0.52675	valid_1's rmse: 1.32168
# [1950]	training's rmse: 0.490338	valid_1's rmse: 1.32172
# Early stopping, best iteration is:
# [1855]	training's rmse: 0.512198	valid_1's rmse: 1.32158
# Model training done in 13.855243444442749 seconds.
# Fold error 1.3215830082287714
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40219	valid_1's rmse: 1.44641
# [300]	training's rmse: 1.2309	valid_1's rmse: 1.34326
# [450]	training's rmse: 1.12217	valid_1's rmse: 1.29985
# [600]	training's rmse: 1.04497	valid_1's rmse: 1.28281
# [750]	training's rmse: 0.983603	valid_1's rmse: 1.2743
# [900]	training's rmse: 0.928928	valid_1's rmse: 1.26738
# [1050]	training's rmse: 0.881338	valid_1's rmse: 1.26365
# [1200]	training's rmse: 0.835634	valid_1's rmse: 1.26123
# [1350]	training's rmse: 0.793082	valid_1's rmse: 1.26053
# [1500]	training's rmse: 0.753159	valid_1's rmse: 1.25993
# [1650]	training's rmse: 0.714482	valid_1's rmse: 1.25894
# Early stopping, best iteration is:
# [1693]	training's rmse: 0.703748	valid_1's rmse: 1.25852
# Model training done in 15.136406898498535 seconds.
# Fold error 1.2585204599538564
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39174	valid_1's rmse: 1.50177
# [300]	training's rmse: 1.21516	valid_1's rmse: 1.41666
# [450]	training's rmse: 1.10398	valid_1's rmse: 1.38585
# [600]	training's rmse: 1.02327	valid_1's rmse: 1.37526
# [750]	training's rmse: 0.958375	valid_1's rmse: 1.3713
# [900]	training's rmse: 0.90162	valid_1's rmse: 1.36987
# Early stopping, best iteration is:
# [927]	training's rmse: 0.89212	valid_1's rmse: 1.36925
# Model training done in 8.927488803863525 seconds.
# Fold error 1.3692467700773712
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39513	valid_1's rmse: 1.4664
# [300]	training's rmse: 1.21749	valid_1's rmse: 1.38639
# [450]	training's rmse: 1.10435	valid_1's rmse: 1.35666
# [600]	training's rmse: 1.02273	valid_1's rmse: 1.34479
# [750]	training's rmse: 0.958716	valid_1's rmse: 1.33975
# [900]	training's rmse: 0.904218	valid_1's rmse: 1.33687
# [1050]	training's rmse: 0.856164	valid_1's rmse: 1.33407
# [1200]	training's rmse: 0.811378	valid_1's rmse: 1.33333
# [1350]	training's rmse: 0.769573	valid_1's rmse: 1.33297
# [1500]	training's rmse: 0.729325	valid_1's rmse: 1.33195
# [1650]	training's rmse: 0.691174	valid_1's rmse: 1.33153
# [1800]	training's rmse: 0.656567	valid_1's rmse: 1.33112
# [1950]	training's rmse: 0.623151	valid_1's rmse: 1.33059
# Early stopping, best iteration is:
# [1982]	training's rmse: 0.616075	valid_1's rmse: 1.33031
# Model training done in 16.807921886444092 seconds.
# Fold error 1.3303096803024426
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3906	valid_1's rmse: 1.47593
# [300]	training's rmse: 1.21021	valid_1's rmse: 1.38759
# [450]	training's rmse: 1.09444	valid_1's rmse: 1.35457
# [600]	training's rmse: 1.01116	valid_1's rmse: 1.34279
# [750]	training's rmse: 0.943576	valid_1's rmse: 1.33716
# [900]	training's rmse: 0.886315	valid_1's rmse: 1.3345
# [1050]	training's rmse: 0.8349	valid_1's rmse: 1.33349
# [1200]	training's rmse: 0.786161	valid_1's rmse: 1.33248
# [1350]	training's rmse: 0.743236	valid_1's rmse: 1.33161
# [1500]	training's rmse: 0.701571	valid_1's rmse: 1.33104
# Early stopping, best iteration is:
# [1453]	training's rmse: 0.71463	valid_1's rmse: 1.33096
# Model training done in 12.443131685256958 seconds.
# Fold error 1.3309565870010605
# Total error 1.32480186704
# Total std 0.03581
# Fitting big fold 10 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.3685	valid_1's rmse: 1.48365
# [300]	training's rmse: 1.16964	valid_1's rmse: 1.39452
# [450]	training's rmse: 1.03964	valid_1's rmse: 1.36094
# [600]	training's rmse: 0.944861	valid_1's rmse: 1.34785
# [750]	training's rmse: 0.868722	valid_1's rmse: 1.34243
# [900]	training's rmse: 0.805402	valid_1's rmse: 1.33964
# [1050]	training's rmse: 0.751297	valid_1's rmse: 1.33821
# [1200]	training's rmse: 0.700942	valid_1's rmse: 1.33749
# [1350]	training's rmse: 0.653402	valid_1's rmse: 1.33639
# [1500]	training's rmse: 0.60945	valid_1's rmse: 1.33602
# [1650]	training's rmse: 0.569405	valid_1's rmse: 1.33537
# Early stopping, best iteration is:
# [1659]	training's rmse: 0.567103	valid_1's rmse: 1.3353
# Model training done in 11.988797187805176 seconds.
# Fold error 1.3353049987068792
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39716	valid_1's rmse: 1.48356
# [300]	training's rmse: 1.22446	valid_1's rmse: 1.4023
# [450]	training's rmse: 1.11538	valid_1's rmse: 1.3693
# [600]	training's rmse: 1.03684	valid_1's rmse: 1.35726
# [750]	training's rmse: 0.97336	valid_1's rmse: 1.35331
# [900]	training's rmse: 0.917917	valid_1's rmse: 1.35068
# [1050]	training's rmse: 0.868799	valid_1's rmse: 1.34867
# Early stopping, best iteration is:
# [1093]	training's rmse: 0.855461	valid_1's rmse: 1.34834
# Model training done in 10.358444929122925 seconds.
# Fold error 1.3483401766264882
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39875	valid_1's rmse: 1.46841
# [300]	training's rmse: 1.22587	valid_1's rmse: 1.36681
# [450]	training's rmse: 1.11594	valid_1's rmse: 1.32543
# [600]	training's rmse: 1.03864	valid_1's rmse: 1.30969
# [750]	training's rmse: 0.976309	valid_1's rmse: 1.29985
# [900]	training's rmse: 0.922682	valid_1's rmse: 1.29385
# [1050]	training's rmse: 0.875275	valid_1's rmse: 1.29157
# [1200]	training's rmse: 0.83145	valid_1's rmse: 1.28977
# [1350]	training's rmse: 0.791774	valid_1's rmse: 1.28832
# [1500]	training's rmse: 0.752628	valid_1's rmse: 1.28702
# [1650]	training's rmse: 0.715021	valid_1's rmse: 1.28559
# [1800]	training's rmse: 0.680301	valid_1's rmse: 1.2846
# [1950]	training's rmse: 0.647008	valid_1's rmse: 1.2837
# Early stopping, best iteration is:
# [1936]	training's rmse: 0.650111	valid_1's rmse: 1.28355
# Model training done in 16.584228992462158 seconds.
# Fold error 1.2835506792953333
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39243	valid_1's rmse: 1.49646
# [300]	training's rmse: 1.21743	valid_1's rmse: 1.4016
# [450]	training's rmse: 1.10453	valid_1's rmse: 1.36302
# [600]	training's rmse: 1.02263	valid_1's rmse: 1.34682
# [750]	training's rmse: 0.958103	valid_1's rmse: 1.33974
# [900]	training's rmse: 0.902666	valid_1's rmse: 1.33554
# [1050]	training's rmse: 0.853469	valid_1's rmse: 1.33256
# [1200]	training's rmse: 0.807435	valid_1's rmse: 1.33091
# [1350]	training's rmse: 0.765808	valid_1's rmse: 1.33053
# [1500]	training's rmse: 0.725714	valid_1's rmse: 1.33027
# [1650]	training's rmse: 0.687226	valid_1's rmse: 1.32943
# Early stopping, best iteration is:
# [1696]	training's rmse: 0.675926	valid_1's rmse: 1.32887
# Model training done in 14.532778978347778 seconds.
# Fold error 1.3288717680745767
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39328	valid_1's rmse: 1.46682
# [300]	training's rmse: 1.21464	valid_1's rmse: 1.37233
# [450]	training's rmse: 1.09942	valid_1's rmse: 1.33428
# [600]	training's rmse: 1.01632	valid_1's rmse: 1.32179
# [750]	training's rmse: 0.94968	valid_1's rmse: 1.31587
# [900]	training's rmse: 0.891456	valid_1's rmse: 1.31267
# [1050]	training's rmse: 0.838603	valid_1's rmse: 1.31223
# Early stopping, best iteration is:
# [1081]	training's rmse: 0.827864	valid_1's rmse: 1.31189
# Model training done in 9.929903984069824 seconds.
# Fold error 1.3118922276801122
# Total error 1.32450029604
# Total std 0.02235
# Fitting big fold 11 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.37661	valid_1's rmse: 1.47391
# [300]	training's rmse: 1.1792	valid_1's rmse: 1.38326
# [450]	training's rmse: 1.05065	valid_1's rmse: 1.34717
# [600]	training's rmse: 0.95707	valid_1's rmse: 1.33397
# [750]	training's rmse: 0.882023	valid_1's rmse: 1.32843
# [900]	training's rmse: 0.818291	valid_1's rmse: 1.32478
# [1050]	training's rmse: 0.758982	valid_1's rmse: 1.32333
# [1200]	training's rmse: 0.706026	valid_1's rmse: 1.32172
# [1350]	training's rmse: 0.656801	valid_1's rmse: 1.32116
# [1500]	training's rmse: 0.612124	valid_1's rmse: 1.32055
# Early stopping, best iteration is:
# [1448]	training's rmse: 0.627174	valid_1's rmse: 1.32032
# Model training done in 11.179324388504028 seconds.
# Fold error 1.3203227715263501
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40187	valid_1's rmse: 1.45027
# [300]	training's rmse: 1.23007	valid_1's rmse: 1.35003
# [450]	training's rmse: 1.12062	valid_1's rmse: 1.31084
# [600]	training's rmse: 1.04247	valid_1's rmse: 1.29688
# [750]	training's rmse: 0.979037	valid_1's rmse: 1.29183
# [900]	training's rmse: 0.923438	valid_1's rmse: 1.29009
# [1050]	training's rmse: 0.875256	valid_1's rmse: 1.28775
# [1200]	training's rmse: 0.829673	valid_1's rmse: 1.28729
# Early stopping, best iteration is:
# [1165]	training's rmse: 0.839932	valid_1's rmse: 1.28705
# Model training done in 10.908509492874146 seconds.
# Fold error 1.2870500287354723
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39196	valid_1's rmse: 1.50465
# [300]	training's rmse: 1.21862	valid_1's rmse: 1.41371
# [450]	training's rmse: 1.10841	valid_1's rmse: 1.37738
# [600]	training's rmse: 1.02897	valid_1's rmse: 1.36273
# [750]	training's rmse: 0.965668	valid_1's rmse: 1.35521
# [900]	training's rmse: 0.910922	valid_1's rmse: 1.35027
# [1050]	training's rmse: 0.862822	valid_1's rmse: 1.348
# [1200]	training's rmse: 0.817383	valid_1's rmse: 1.34489
# [1350]	training's rmse: 0.775801	valid_1's rmse: 1.34434
# [1500]	training's rmse: 0.738131	valid_1's rmse: 1.34331
# [1650]	training's rmse: 0.70137	valid_1's rmse: 1.34277
# [1800]	training's rmse: 0.665004	valid_1's rmse: 1.34227
# [1950]	training's rmse: 0.631946	valid_1's rmse: 1.34218
# Early stopping, best iteration is:
# [1857]	training's rmse: 0.652142	valid_1's rmse: 1.34194
# Model training done in 16.145267724990845 seconds.
# Fold error 1.3419350652770379
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39438	valid_1's rmse: 1.47556
# [300]	training's rmse: 1.21733	valid_1's rmse: 1.38935
# [450]	training's rmse: 1.1057	valid_1's rmse: 1.3546
# [600]	training's rmse: 1.025	valid_1's rmse: 1.34007
# [750]	training's rmse: 0.960885	valid_1's rmse: 1.33366
# [900]	training's rmse: 0.90464	valid_1's rmse: 1.32934
# [1050]	training's rmse: 0.856913	valid_1's rmse: 1.32712
# [1200]	training's rmse: 0.811857	valid_1's rmse: 1.32651
# [1350]	training's rmse: 0.768746	valid_1's rmse: 1.32612
# [1500]	training's rmse: 0.729268	valid_1's rmse: 1.32542
# [1650]	training's rmse: 0.691408	valid_1's rmse: 1.32472
# [1800]	training's rmse: 0.655766	valid_1's rmse: 1.32458
# Early stopping, best iteration is:
# [1754]	training's rmse: 0.666309	valid_1's rmse: 1.3244
# Model training done in 15.15575122833252 seconds.
# Fold error 1.3244039664642466
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38467	valid_1's rmse: 1.50833
# [300]	training's rmse: 1.20442	valid_1's rmse: 1.41835
# [450]	training's rmse: 1.08871	valid_1's rmse: 1.38249
# [600]	training's rmse: 1.00525	valid_1's rmse: 1.3697
# [750]	training's rmse: 0.937513	valid_1's rmse: 1.3634
# [900]	training's rmse: 0.878987	valid_1's rmse: 1.35939
# [1050]	training's rmse: 0.824676	valid_1's rmse: 1.35687
# [1200]	training's rmse: 0.775041	valid_1's rmse: 1.35602
# [1350]	training's rmse: 0.729733	valid_1's rmse: 1.3539
# Early stopping, best iteration is:
# [1372]	training's rmse: 0.723535	valid_1's rmse: 1.35364
# Model training done in 12.329549074172974 seconds.
# Fold error 1.3536374326577179
# Total error 1.32704674704
# Total std 0.02266
# Fitting big fold 12 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.37682	valid_1's rmse: 1.47352
# [300]	training's rmse: 1.17982	valid_1's rmse: 1.38106
# [450]	training's rmse: 1.04892	valid_1's rmse: 1.3457
# [600]	training's rmse: 0.954844	valid_1's rmse: 1.33271
# [750]	training's rmse: 0.877969	valid_1's rmse: 1.32657
# [900]	training's rmse: 0.81238	valid_1's rmse: 1.324
# [1050]	training's rmse: 0.754356	valid_1's rmse: 1.32269
# [1200]	training's rmse: 0.703109	valid_1's rmse: 1.32183
# [1350]	training's rmse: 0.652961	valid_1's rmse: 1.32172
# [1500]	training's rmse: 0.606489	valid_1's rmse: 1.32112
# [1650]	training's rmse: 0.5626	valid_1's rmse: 1.32106
# Early stopping, best iteration is:
# [1581]	training's rmse: 0.582598	valid_1's rmse: 1.32093
# Model training done in 12.771976232528687 seconds.
# Fold error 1.3209331319530264
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40051	valid_1's rmse: 1.46076
# [300]	training's rmse: 1.22857	valid_1's rmse: 1.36433
# [450]	training's rmse: 1.11889	valid_1's rmse: 1.32738
# [600]	training's rmse: 1.04038	valid_1's rmse: 1.31403
# [750]	training's rmse: 0.976473	valid_1's rmse: 1.30911
# [900]	training's rmse: 0.921065	valid_1's rmse: 1.30654
# [1050]	training's rmse: 0.872373	valid_1's rmse: 1.305
# Early stopping, best iteration is:
# [1015]	training's rmse: 0.884058	valid_1's rmse: 1.30488
# Model training done in 9.784576177597046 seconds.
# Fold error 1.304876238220061
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39424	valid_1's rmse: 1.50754
# [300]	training's rmse: 1.22125	valid_1's rmse: 1.41323
# [450]	training's rmse: 1.11172	valid_1's rmse: 1.37439
# [600]	training's rmse: 1.03323	valid_1's rmse: 1.35812
# [750]	training's rmse: 0.969552	valid_1's rmse: 1.35002
# [900]	training's rmse: 0.915162	valid_1's rmse: 1.34455
# [1050]	training's rmse: 0.867776	valid_1's rmse: 1.34191
# [1200]	training's rmse: 0.822424	valid_1's rmse: 1.34042
# [1350]	training's rmse: 0.780243	valid_1's rmse: 1.33903
# [1500]	training's rmse: 0.741287	valid_1's rmse: 1.33782
# Early stopping, best iteration is:
# [1435]	training's rmse: 0.758315	valid_1's rmse: 1.33774
# ...
# Early stopping, best iteration is:
# [1176]	training's rmse: 0.831264	valid_1's rmse: 1.33453
# Model training done in 11.174862146377563 seconds.
# Fold error 1.3345275388010114
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39837	valid_1's rmse: 1.47036
# [300]	training's rmse: 1.22448	valid_1's rmse: 1.38218
# [450]	training's rmse: 1.11434	valid_1's rmse: 1.34801
# [600]	training's rmse: 1.03487	valid_1's rmse: 1.33256
# [750]	training's rmse: 0.970533	valid_1's rmse: 1.32487
# [900]	training's rmse: 0.914714	valid_1's rmse: 1.3202
# [1050]	training's rmse: 0.866251	valid_1's rmse: 1.31652
# [1200]	training's rmse: 0.820859	valid_1's rmse: 1.31506
# [1350]	training's rmse: 0.778749	valid_1's rmse: 1.31297
# [1500]	training's rmse: 0.739309	valid_1's rmse: 1.31174
# [1650]	training's rmse: 0.701329	valid_1's rmse: 1.31132
# [1800]	training's rmse: 0.666878	valid_1's rmse: 1.31051
# [1950]	training's rmse: 0.63424	valid_1's rmse: 1.30926
# [2100]	training's rmse: 0.602315	valid_1's rmse: 1.30872
# [2250]	training's rmse: 0.572691	valid_1's rmse: 1.30847
# Early stopping, best iteration is:
# [2221]	training's rmse: 0.578265	valid_1's rmse: 1.3082
# Model training done in 18.89905619621277 seconds.
# Fold error 1.3081959200786952
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38949	valid_1's rmse: 1.50652
# [300]	training's rmse: 1.21419	valid_1's rmse: 1.40877
# [450]	training's rmse: 1.10314	valid_1's rmse: 1.36987
# [600]	training's rmse: 1.02304	valid_1's rmse: 1.35592
# [750]	training's rmse: 0.958462	valid_1's rmse: 1.34974
# [900]	training's rmse: 0.901271	valid_1's rmse: 1.34563
# [1050]	training's rmse: 0.850742	valid_1's rmse: 1.34378
# [1200]	training's rmse: 0.803764	valid_1's rmse: 1.34207
# [1350]	training's rmse: 0.759549	valid_1's rmse: 1.34095
# [1500]	training's rmse: 0.718488	valid_1's rmse: 1.33968
# [1650]	training's rmse: 0.679439	valid_1's rmse: 1.33942
# [1800]	training's rmse: 0.642978	valid_1's rmse: 1.33863
# [1950]	training's rmse: 0.608555	valid_1's rmse: 1.33838
# Early stopping, best iteration is:
# [1914]	training's rmse: 0.6169	valid_1's rmse: 1.33816
# Model training done in 16.724102020263672 seconds.
# Fold error 1.3381601216318955
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39785	valid_1's rmse: 1.4527
# [300]	training's rmse: 1.21892	valid_1's rmse: 1.35069
# [450]	training's rmse: 1.10374	valid_1's rmse: 1.30861
# [600]	training's rmse: 1.02105	valid_1's rmse: 1.29316
# [750]	training's rmse: 0.954441	valid_1's rmse: 1.28721
# [900]	training's rmse: 0.896775	valid_1's rmse: 1.28484
# [1050]	training's rmse: 0.845025	valid_1's rmse: 1.28369
# [1200]	training's rmse: 0.797665	valid_1's rmse: 1.28285
# [1350]	training's rmse: 0.75501	valid_1's rmse: 1.2824
# Early stopping, best iteration is:
# [1365]	training's rmse: 0.750847	valid_1's rmse: 1.28235
# Model training done in 12.142553806304932 seconds.
# Fold error 1.2823473220580726
# Total error 1.3278010545
# Total std 0.02431
# Fitting big fold 18 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.37048	valid_1's rmse: 1.48394
# [300]	training's rmse: 1.17545	valid_1's rmse: 1.3892
# [450]	training's rmse: 1.04564	valid_1's rmse: 1.3509
# [600]	training's rmse: 0.948612	valid_1's rmse: 1.33628
# [750]	training's rmse: 0.868199	valid_1's rmse: 1.32981
# [900]	training's rmse: 0.800148	valid_1's rmse: 1.32705
# [1050]	training's rmse: 0.740536	valid_1's rmse: 1.32586
# [1200]	training's rmse: 0.686862	valid_1's rmse: 1.32521
# Early stopping, best iteration is:
# [1160]	training's rmse: 0.701088	valid_1's rmse: 1.32509
# Model training done in 9.195328950881958 seconds.
# Fold error 1.3250884229052262
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40746	valid_1's rmse: 1.38484
# [300]	training's rmse: 1.23697	valid_1's rmse: 1.27775
# [450]	training's rmse: 1.12759	valid_1's rmse: 1.23613
# [600]	training's rmse: 1.04864	valid_1's rmse: 1.22044
# [750]	training's rmse: 0.985119	valid_1's rmse: 1.21125
# [900]	training's rmse: 0.930123	valid_1's rmse: 1.20679
# [1050]	training's rmse: 0.882455	valid_1's rmse: 1.2034
# [1200]	training's rmse: 0.83759	valid_1's rmse: 1.20126
# [1350]	training's rmse: 0.796328	valid_1's rmse: 1.19887
# Early stopping, best iteration is:
# [1394]	training's rmse: 0.784932	valid_1's rmse: 1.19801
# Model training done in 12.568620920181274 seconds.
# Fold error 1.1980061032032403
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40066	valid_1's rmse: 1.45701
# [300]	training's rmse: 1.22747	valid_1's rmse: 1.36526
# [450]	training's rmse: 1.11802	valid_1's rmse: 1.32653
# [600]	training's rmse: 1.03863	valid_1's rmse: 1.31018
# [750]	training's rmse: 0.975745	valid_1's rmse: 1.30138
# [900]	training's rmse: 0.921655	valid_1's rmse: 1.29655
# [1050]	training's rmse: 0.87405	valid_1's rmse: 1.29337
# [1200]	training's rmse: 0.829062	valid_1's rmse: 1.29193
# [1350]	training's rmse: 0.787329	valid_1's rmse: 1.29052
# [1500]	training's rmse: 0.748046	valid_1's rmse: 1.28928
# [1650]	training's rmse: 0.711118	valid_1's rmse: 1.28803
# [1800]	training's rmse: 0.675636	valid_1's rmse: 1.28781
# [1950]	training's rmse: 0.642685	valid_1's rmse: 1.28676
# [2100]	training's rmse: 0.611526	valid_1's rmse: 1.28635
# Early stopping, best iteration is:
# [2015]	training's rmse: 0.628837	valid_1's rmse: 1.28625
# Model training done in 16.906627893447876 seconds.
# Fold error 1.2862526805664043
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38837	valid_1's rmse: 1.50143
# [300]	training's rmse: 1.20956	valid_1's rmse: 1.42148
# [450]	training's rmse: 1.09572	valid_1's rmse: 1.39178
# [600]	training's rmse: 1.01607	valid_1's rmse: 1.37896
# [750]	training's rmse: 0.950624	valid_1's rmse: 1.37261
# [900]	training's rmse: 0.894607	valid_1's rmse: 1.36888
# [1050]	training's rmse: 0.845947	valid_1's rmse: 1.36817
# [1200]	training's rmse: 0.799583	valid_1's rmse: 1.3672
# [1350]	training's rmse: 0.756515	valid_1's rmse: 1.36645
# Early stopping, best iteration is:
# [1393]	training's rmse: 0.744205	valid_1's rmse: 1.36595
# Model training done in 12.478843688964844 seconds.
# Fold error 1.3659452749511016
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38116	valid_1's rmse: 1.52524
# [300]	training's rmse: 1.20169	valid_1's rmse: 1.43679
# [450]	training's rmse: 1.08649	valid_1's rmse: 1.40175
# [600]	training's rmse: 1.00454	valid_1's rmse: 1.38883
# [750]	training's rmse: 0.939487	valid_1's rmse: 1.38364
# [900]	training's rmse: 0.884174	valid_1's rmse: 1.38017
# [1050]	training's rmse: 0.835947	valid_1's rmse: 1.37827
# [1200]	training's rmse: 0.790213	valid_1's rmse: 1.37787
# [1350]	training's rmse: 0.746976	valid_1's rmse: 1.37611
# [1500]	training's rmse: 0.706472	valid_1's rmse: 1.37569
# [1650]	training's rmse: 0.66792	valid_1's rmse: 1.37544
# Early stopping, best iteration is:
# [1614]	training's rmse: 0.677301	valid_1's rmse: 1.37522
# Model training done in 14.756968021392822 seconds.
# Fold error 1.3752169462801456
# Total error 1.32505984149
# Total std 0.06437
# Fitting big fold 19 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.35959	valid_1's rmse: 1.50829
# [300]	training's rmse: 1.16119	valid_1's rmse: 1.41962
# [450]	training's rmse: 1.03128	valid_1's rmse: 1.38302
# [600]	training's rmse: 0.936239	valid_1's rmse: 1.36941
# [750]	training's rmse: 0.85871	valid_1's rmse: 1.36216
# [900]	training's rmse: 0.791486	valid_1's rmse: 1.3591
# [1050]	training's rmse: 0.733121	valid_1's rmse: 1.35782
# [1200]	training's rmse: 0.679822	valid_1's rmse: 1.35759
# Early stopping, best iteration is:
# [1149]	training's rmse: 0.698409	valid_1's rmse: 1.35739
# Model training done in 9.566336154937744 seconds.
# Fold error 1.357394309344384
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40401	valid_1's rmse: 1.40057
# [300]	training's rmse: 1.22929	valid_1's rmse: 1.32113
# [450]	training's rmse: 1.11904	valid_1's rmse: 1.29565
# [600]	training's rmse: 1.03957	valid_1's rmse: 1.28756
# [750]	training's rmse: 0.976141	valid_1's rmse: 1.28573
# [900]	training's rmse: 0.919241	valid_1's rmse: 1.28408
# [1050]	training's rmse: 0.869889	valid_1's rmse: 1.28295
# [1200]	training's rmse: 0.824696	valid_1's rmse: 1.28206
# [1350]	training's rmse: 0.782737	valid_1's rmse: 1.28183
# [1500]	training's rmse: 0.74245	valid_1's rmse: 1.28147
# Early stopping, best iteration is:
# [1408]	training's rmse: 0.7676	valid_1's rmse: 1.28108
# Model training done in 13.428183794021606 seconds.
# Fold error 1.2810790661102454
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39938	valid_1's rmse: 1.46623
# [300]	training's rmse: 1.22912	valid_1's rmse: 1.35927
# [450]	training's rmse: 1.12111	valid_1's rmse: 1.31423
# [600]	training's rmse: 1.04206	valid_1's rmse: 1.29425
# [750]	training's rmse: 0.978518	valid_1's rmse: 1.28317
# [900]	training's rmse: 0.923322	valid_1's rmse: 1.27509
# [1050]	training's rmse: 0.872974	valid_1's rmse: 1.27103
# [1200]	training's rmse: 0.828138	valid_1's rmse: 1.2677
# [1350]	training's rmse: 0.786176	valid_1's rmse: 1.2652
# [1500]	training's rmse: 0.747355	valid_1's rmse: 1.26406
# [1650]	training's rmse: 0.710211	valid_1's rmse: 1.26266
# [1800]	training's rmse: 0.676697	valid_1's rmse: 1.26195
# [1950]	training's rmse: 0.644018	valid_1's rmse: 1.26131
# Early stopping, best iteration is:
# [1885]	training's rmse: 0.658494	valid_1's rmse: 1.26086
# Model training done in 16.321349143981934 seconds.
# Fold error 1.2608645418125424
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39643	valid_1's rmse: 1.46521
# [300]	training's rmse: 1.21917	valid_1's rmse: 1.37144
# [450]	training's rmse: 1.10612	valid_1's rmse: 1.33704
# [600]	training's rmse: 1.02502	valid_1's rmse: 1.32445
# [750]	training's rmse: 0.958286	valid_1's rmse: 1.31897
# [900]	training's rmse: 0.900686	valid_1's rmse: 1.3168
# [1050]	training's rmse: 0.850693	valid_1's rmse: 1.31512
# [1200]	training's rmse: 0.803379	valid_1's rmse: 1.31374
# [1350]	training's rmse: 0.759205	valid_1's rmse: 1.31313
# [1500]	training's rmse: 0.718965	valid_1's rmse: 1.31386
# Early stopping, best iteration is:
# [1419]	training's rmse: 0.740543	valid_1's rmse: 1.31268
# Model training done in 12.531419277191162 seconds.
# Fold error 1.312681838019048
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38616	valid_1's rmse: 1.50164
# [300]	training's rmse: 1.20669	valid_1's rmse: 1.41478
# [450]	training's rmse: 1.09322	valid_1's rmse: 1.3778
# [600]	training's rmse: 1.01061	valid_1's rmse: 1.3649
# [750]	training's rmse: 0.943521	valid_1's rmse: 1.35888
# [900]	training's rmse: 0.885961	valid_1's rmse: 1.35598
# [1050]	training's rmse: 0.834974	valid_1's rmse: 1.3544
# [1200]	training's rmse: 0.787464	valid_1's rmse: 1.35417
# [1350]	training's rmse: 0.743532	valid_1's rmse: 1.35292
# [1500]	training's rmse: 0.701989	valid_1's rmse: 1.35221
# [1650]	training's rmse: 0.663677	valid_1's rmse: 1.35201
# Early stopping, best iteration is:
# [1565]	training's rmse: 0.685784	valid_1's rmse: 1.3516
# Model training done in 13.532345533370972 seconds.
# Fold error 1.3515954720696965
# Total error 1.32894223776
# Total std 0.03794
# Fitting big fold 20 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38002	valid_1's rmse: 1.47392
# [300]	training's rmse: 1.18369	valid_1's rmse: 1.38186
# [450]	training's rmse: 1.05377	valid_1's rmse: 1.34323
# [600]	training's rmse: 0.959234	valid_1's rmse: 1.32821
# [750]	training's rmse: 0.882534	valid_1's rmse: 1.32088
# [900]	training's rmse: 0.817132	valid_1's rmse: 1.31675
# [1050]	training's rmse: 0.759589	valid_1's rmse: 1.31487
# [1200]	training's rmse: 0.704314	valid_1's rmse: 1.31387
# [1350]	training's rmse: 0.653972	valid_1's rmse: 1.313
# [1500]	training's rmse: 0.607923	valid_1's rmse: 1.31267
# [1650]	training's rmse: 0.5638	valid_1's rmse: 1.31266
# Early stopping, best iteration is:
# [1551]	training's rmse: 0.592972	valid_1's rmse: 1.31257
# Model training done in 11.605885028839111 seconds.
# Fold error 1.3125706043796377
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39398	valid_1's rmse: 1.50188
# [300]	training's rmse: 1.22156	valid_1's rmse: 1.40586
# [450]	training's rmse: 1.11176	valid_1's rmse: 1.37265
# [600]	training's rmse: 1.03242	valid_1's rmse: 1.35933
# [750]	training's rmse: 0.970347	valid_1's rmse: 1.35466
# [900]	training's rmse: 0.916423	valid_1's rmse: 1.3526
# [1050]	training's rmse: 0.868455	valid_1's rmse: 1.35118
# [1200]	training's rmse: 0.825407	valid_1's rmse: 1.34959
# Early stopping, best iteration is:
# [1244]	training's rmse: 0.812818	valid_1's rmse: 1.34924
# Model training done in 11.428813219070435 seconds.
# Fold error 1.3492442231009851
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39752	valid_1's rmse: 1.46985
# [300]	training's rmse: 1.22329	valid_1's rmse: 1.38487
# [450]	training's rmse: 1.11395	valid_1's rmse: 1.3515
# [600]	training's rmse: 1.03522	valid_1's rmse: 1.3388
# [750]	training's rmse: 0.971206	valid_1's rmse: 1.33406
# [900]	training's rmse: 0.916857	valid_1's rmse: 1.33042
# [1050]	training's rmse: 0.868755	valid_1's rmse: 1.32901
# [1200]	training's rmse: 0.823319	valid_1's rmse: 1.32734
# [1350]	training's rmse: 0.78004	valid_1's rmse: 1.32661
# [1500]	training's rmse: 0.739798	valid_1's rmse: 1.32617
# [1650]	training's rmse: 0.702117	valid_1's rmse: 1.32573
# Early stopping, best iteration is:
# [1575]	training's rmse: 0.720768	valid_1's rmse: 1.32551
# Model training done in 14.461848258972168 seconds.
# Fold error 1.3255085640256676
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39652	valid_1's rmse: 1.46608
# [300]	training's rmse: 1.21982	valid_1's rmse: 1.37176
# [450]	training's rmse: 1.10563	valid_1's rmse: 1.33514
# [600]	training's rmse: 1.02375	valid_1's rmse: 1.32141
# [750]	training's rmse: 0.957642	valid_1's rmse: 1.31594
# [900]	training's rmse: 0.899658	valid_1's rmse: 1.31173
# [1050]	training's rmse: 0.848047	valid_1's rmse: 1.30906
# [1200]	training's rmse: 0.799302	valid_1's rmse: 1.30735
# [1350]	training's rmse: 0.756151	valid_1's rmse: 1.30636
# [1500]	training's rmse: 0.715334	valid_1's rmse: 1.30571
# [1650]	training's rmse: 0.677133	valid_1's rmse: 1.30494
# [1800]	training's rmse: 0.641434	valid_1's rmse: 1.30416
# [1950]	training's rmse: 0.608345	valid_1's rmse: 1.3039
# Early stopping, best iteration is:
# [1979]	training's rmse: 0.602342	valid_1's rmse: 1.30365
# Model training done in 17.12536382675171 seconds.
# Fold error 1.3036507782988482
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.38377	valid_1's rmse: 1.51322
# [300]	training's rmse: 1.20531	valid_1's rmse: 1.42219
# [450]	training's rmse: 1.09271	valid_1's rmse: 1.38646
# [600]	training's rmse: 1.01019	valid_1's rmse: 1.37195
# [750]	training's rmse: 0.943453	valid_1's rmse: 1.36518
# [900]	training's rmse: 0.886616	valid_1's rmse: 1.36126
# [1050]	training's rmse: 0.837109	valid_1's rmse: 1.35889
# [1200]	training's rmse: 0.791445	valid_1's rmse: 1.35778
# [1350]	training's rmse: 0.749355	valid_1's rmse: 1.3572
# [1500]	training's rmse: 0.708911	valid_1's rmse: 1.35672
# Early stopping, best iteration is:
# [1516]	training's rmse: 0.704779	valid_1's rmse: 1.35653
# Model training done in 12.940618753433228 seconds.
# Fold error 1.3565258431727125
# Total error 1.32541059114
# Total std 0.02045
# Wall time: 26min 35s

# %%
print('Avg error:', np.mean(fold_errors))
print('Avg std:', np.mean(fold_std))
# Out:
# Avg error: 1.3209006768
# Avg std: 0.0280805

# %%
# ERRORS
# errors = pd.DataFrame(fold_errors)
# errors.to_csv(os.path.join(PATH_TO_DATA, 'output/20_fold_errors_lgb_cv1340_std0022.csv'), index=False, header=False)

# 20x TRAIN TARGET OOF PREDS
with open(os.path.join(PATH_TO_DATA, 'output/nikita_train_20_folds_lgb_cv1320_std0028.pkl'), 'wb') as f:
    pickle.dump(y_oof_lgb, f)

# 20x TEST PREDS
with open(os.path.join(PATH_TO_DATA, 'output/nikita_test_20_folds_lgb_cv1320_std0028.pkl'), 'wb') as f:
    pickle.dump(pred_test_list_lgb, f)
