# %%
import os
import gc
import time
import pickle

import pandas as pd
import numpy as np

import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedShuffleSplit

# %%
PATH_TO_DATA = ('D:/Py/DataFrames/Santander_Value_Prediction_Challenge(KAGGLE)/')

# %% [markdown]
# ## Reading and joining data

# %%
y = pd.read_csv(os.path.join(PATH_TO_DATA, 'input/train.csv'), usecols=['target'])
y = np.log1p(y.target.values)
print('Target length:', len(y))
# Out:
# Target length: 4459

# %%
# %%time
train_df_statistic_and_bin = pd.read_csv(os.path.join(PATH_TO_DATA, 'train_with_row_statistic_and_bin_thresh098.csv'))
test_df_statistic_and_bin = pd.read_csv(os.path.join(PATH_TO_DATA, 'test_with_row_statistic_and_bin_thresh098.csv'))

train_space_reduction = pd.read_csv(os.path.join(PATH_TO_DATA, 'train_space_reduction_50comp.csv'))
test_space_reduction = pd.read_csv(os.path.join(PATH_TO_DATA, 'test_space_reduction_50comp.csv'))
# Out:
# Wall time: 1min 50s

# %%
# Use only FA and SRP features
cols_to_drop = [x for x in train_space_reduction.columns if str(x)[:2] not in ['fa', 'sr']]
print('Drop', len(cols_to_drop), 'columns')
train_space_reduction = train_space_reduction.drop(cols_to_drop, axis=1, inplace=True)
test_space_reduction = test_space_reduction.drop(cols_to_drop, axis=1, inplace=True)
# Out:
# Drop 600 columns

# %%
# %%time
train_df = pd.concat([train_df_statistic_and_bin, train_space_reduction], axis=1)
test_df = pd.concat([test_df_statistic_and_bin, test_space_reduction], axis=1)

del train_df_statistic_and_bin, test_df_statistic_and_bin
del train_space_reduction, test_space_reduction
gc.collect()

print('Train:', train_df.shape)
print('Test:', test_df.shape)
# Out:
# Train: (4459, 4264)
# Test: (49342, 4264)
# Wall time: 2.54 s

# %% [markdown]
# ## CV Folds

# %%
def get_20_cv_splits(data, in_path):
    #stratify_classes = y
    train = pd.read_csv(os.path.join(PATH_TO_DATA, 'input/train.csv'), usecols=['target'])
    stratify_classes =  train.target.apply(lambda x: int(np.log10(x)))
    splits = {}
    for random_state in range(20):
        column = np.zeros(data.shape[0])
        sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=random_state)
        for i, (_, test_index) in enumerate(sss.split(data, stratify_classes)):
            column[test_index] = i

        splits["split{}".format(random_state)] = column

    pd.DataFrame(splits, index=data.index).to_csv(os.path.join(PATH_TO_DATA, in_path))

# %%
# function to generate 100 folds from create_folds_from_cv_splits func
def create_folds_from_cv_splits(in_path, pkl_path):
    
    cv_splits = pd.read_csv(os.path.join(PATH_TO_DATA, in_path))
    folds_list = []
    for ind, i in enumerate(cv_splits.columns[1:]):
        folds = list(set(cv_splits[i].values))
        folds_list.append([])
        for m in folds:
            val_idx = list(cv_splits[cv_splits[i]==m].index)
            train_idx = list(set(list(cv_splits.index)) - set(val_idx))
            folds_list[ind].append((train_idx, val_idx))
    with open(os.path.join(PATH_TO_DATA, pkl_path), 'wb') as f:
        pickle.dump(folds_list, f)
    return folds_list

# %%
LOAD_CV = False

if LOAD_CV:
    with open(os.path.join(PATH_TO_DATA, 'folds/custom_cv_thresh098.pkl'), 'rb') as f:
        cv_folds = pickle.load(f)
else:
    get_20_cv_splits(train_df, in_path='folds/cv_splits_cleandata_stat_bin_red_thresh098.csv')
    cv_folds = create_folds_from_cv_splits(in_path='folds/cv_splits_cleandata_stat_bin_red_thresh098.csv',
                                           pkl_path='folds/custom_cv_thresh098.pkl')

# %% [markdown]
# ## XGBoost

# %%
def run_xgb(train_X, train_y, val_X, val_y, test_X):
    params = {
        'objective': 'reg:linear',
        'booster': 'gbtree',
        'metric': 'rmse',
        'learning_rate': 0.005,
        'max_depth': 8,
        'subsample': 0.7,
        'colsample_bytree': 0.1,
        'alpha':0,
        'lambda': 0,
        'gamma': 1.5,
        'silent': True,
        'random_state': 44,
        'nthread': -1
    }
    
    start_time = time.time()
    xgtrain = xgb.DMatrix(train_X, label=train_y)
    xgval = xgb.DMatrix(val_X, label=val_y)
    xgtest = xgb.DMatrix(test_X)
    watchlist = [(xgtrain, 'train'), (xgval, 'valid')]
    model = xgb.train(params, xgtrain, 2000, watchlist, 
                      early_stopping_rounds=50, 
                      verbose_eval=100)
    print('Model training done in {} seconds.'.format(time.time() - start_time))
    
    pred_test_y = np.expm1(model.predict(xgtest, ntree_limit=model.best_ntree_limit))
    pred_oof_log = model.predict(xgval, ntree_limit=model.best_ntree_limit)
    return pred_test_y, pred_oof_log, model

# %% [markdown]
# ## LightGBM

# %%
def run_lgb(train_X, train_y, val_X, val_y, test_X):
    params = {
        "objective" : "regression",
        "metric" : "rmse",
        "num_leaves" : 40,
        'max_depth': 8, # -1,
        "learning_rate" : 0.005,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.1, # 0.6,
        "bagging_frequency" : 6,
        "bagging_seed" : 44,
        "verbosity" : -1,
        'num_threads' : 4,
        "seed": 44
    }
    
    start_time = time.time()
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    model = lgb.train(params, lgtrain, 5000, 
                      valid_sets=[lgtrain, lgval], 
                      early_stopping_rounds=100, 
                      verbose_eval=150)
    print('Model training done in {} seconds.'.format(time.time() - start_time))
    
    pred_test_y = np.expm1(model.predict(test_X, num_iteration=model.best_iteration))
    pred_oof_log = model.predict(val_X, num_iteration=model.best_iteration)
    return pred_test_y, pred_oof_log, model

# %%
def run_calculations(X, test, big_cv_folds, func_name = None):
    if not func_name:
        return print('The function to run is not defined')
    else:
        y_oof_20_preds = []
        fold_errors_20_preds =[]
        avg_test_pred_20_preds = []
        fold_errors_std = []
        
        for ind, cv_folds in enumerate(big_cv_folds):
            print('Fitting big fold', ind+1, 'out of', len(big_cv_folds))
            y_oof = np.zeros((y.shape[0]))
            fold_errors =[]
            pred_test_list = []
            
            for i, (train_index, val_index) in enumerate(cv_folds):
                print('Fitting sub fold', i+1, 'out of', len(cv_folds))
                X_train, X_val  = X.iloc[train_index], X.iloc[val_index]
                y_train, y_val = y[train_index], y[val_index]

                # part to include additional functions
                if func_name == 'lgb':
                    pred_test_y, pred_oof_log, clf = run_lgb(X_train, y_train, X_val, y_val, test)
                elif func_name == 'xgb':
                    pred_test_y, pred_oof_log, clf = run_xgb(X_train, y_train, X_val, y_val, test)
                else:
                    return print('The function to run is not correct')

                y_oof[val_index] = pred_oof_log
                curr_fe = np.sqrt(mean_squared_error(y_val, pred_oof_log))
                print(f'Fold error {curr_fe}')
                fold_errors.append(curr_fe)
                pred_test_list.append(list(pred_test_y))

            print('Total error', np.sqrt(mean_squared_error(y, y_oof)))
            total_fe_std = round(np.std(fold_errors), 5)
            print(f'Total std {total_fe_std}')
            avg_test_pred = np.mean(pred_test_list, axis=0)
            
            avg_test_pred_20_preds.append(avg_test_pred)
            fold_errors_20_preds.append(fold_errors)
            y_oof_20_preds.append(y_oof)
            fold_errors_std.append(total_fe_std)
            
        return y_oof_20_preds, avg_test_pred_20_preds, fold_errors_20_preds, fold_errors_std

# %% [markdown]
# ---

# %%
# %%time
y_oof_lgb, pred_test_list_lgb, fold_errors, fold_std = run_calculations(train_df, test_df, cv_folds, 'lgb')
# Out:
# Fitting big fold 1 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41342	valid_1's rmse: 1.48133
# [300]	training's rmse: 1.25129	valid_1's rmse: 1.38516
# [450]	training's rmse: 1.1597	valid_1's rmse: 1.34971
# [600]	training's rmse: 1.09648	valid_1's rmse: 1.33414
# [750]	training's rmse: 1.05199	valid_1's rmse: 1.32888
# [900]	training's rmse: 1.01819	valid_1's rmse: 1.32769
# [1050]	training's rmse: 0.991393	valid_1's rmse: 1.3276
# Early stopping, best iteration is:
# [999]	training's rmse: 1.00024	valid_1's rmse: 1.32752
# Model training done in 21.002872228622437 seconds.
# Fold error 1.3275214733499638
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42497	valid_1's rmse: 1.45788
# [300]	training's rmse: 1.27312	valid_1's rmse: 1.34938
# [450]	training's rmse: 1.19072	valid_1's rmse: 1.31285
# [600]	training's rmse: 1.13402	valid_1's rmse: 1.29862
# [750]	training's rmse: 1.09619	valid_1's rmse: 1.29297
# [900]	training's rmse: 1.0666	valid_1's rmse: 1.28989
# [1050]	training's rmse: 1.04375	valid_1's rmse: 1.28919
# [1200]	training's rmse: 1.02399	valid_1's rmse: 1.29005
# Early stopping, best iteration is:
# [1103]	training's rmse: 1.03639	valid_1's rmse: 1.28894
# Model training done in 30.908325672149658 seconds.
# Fold error 1.2889412341813484
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42231	valid_1's rmse: 1.46915
# [300]	training's rmse: 1.26866	valid_1's rmse: 1.37562
# [450]	training's rmse: 1.18441	valid_1's rmse: 1.34255
# [600]	training's rmse: 1.12705	valid_1's rmse: 1.33061
# [750]	training's rmse: 1.0884	valid_1's rmse: 1.32696
# [900]	training's rmse: 1.05735	valid_1's rmse: 1.32685
# Early stopping, best iteration is:
# [888]	training's rmse: 1.05953	valid_1's rmse: 1.32662
# Model training done in 28.123263359069824 seconds.
# Fold error 1.3266235847730163
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41252	valid_1's rmse: 1.52861
# [300]	training's rmse: 1.25739	valid_1's rmse: 1.43701
# [450]	training's rmse: 1.17183	valid_1's rmse: 1.40703
# [600]	training's rmse: 1.11358	valid_1's rmse: 1.39566
# [750]	training's rmse: 1.07504	valid_1's rmse: 1.39087
# [900]	training's rmse: 1.04347	valid_1's rmse: 1.38802
# [1050]	training's rmse: 1.02032	valid_1's rmse: 1.38658
# [1200]	training's rmse: 1.00166	valid_1's rmse: 1.38627
# [1350]	training's rmse: 0.985035	valid_1's rmse: 1.38663
# Early stopping, best iteration is:
# [1250]	training's rmse: 0.996415	valid_1's rmse: 1.38594
# Model training done in 32.03941059112549 seconds.
# Fold error 1.3859367570736931
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41702	valid_1's rmse: 1.48852
# [300]	training's rmse: 1.25877	valid_1's rmse: 1.40087
# [450]	training's rmse: 1.17309	valid_1's rmse: 1.37048
# [600]	training's rmse: 1.114	valid_1's rmse: 1.35852
# [750]	training's rmse: 1.07441	valid_1's rmse: 1.35478
# [900]	training's rmse: 1.0428	valid_1's rmse: 1.35339
# [1050]	training's rmse: 1.02087	valid_1's rmse: 1.35375
# Early stopping, best iteration is:
# [990]	training's rmse: 1.0294	valid_1's rmse: 1.35323
# Model training done in 26.30403757095337 seconds.
# Fold error 1.3532286671686489
# Total error 1.33836850585
# Total std 0.03214
# Fitting big fold 2 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.39633	valid_1's rmse: 1.50121
# [300]	training's rmse: 1.22623	valid_1's rmse: 1.4166
# [450]	training's rmse: 1.13269	valid_1's rmse: 1.38816
# [600]	training's rmse: 1.06908	valid_1's rmse: 1.37728
# [750]	training's rmse: 1.02498	valid_1's rmse: 1.3743
# [900]	training's rmse: 0.990914	valid_1's rmse: 1.37366
# Early stopping, best iteration is:
# [845]	training's rmse: 1.00224	valid_1's rmse: 1.37352
# Model training done in 19.05698585510254 seconds.
# Fold error 1.3735172428164053
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42893	valid_1's rmse: 1.43971
# [300]	training's rmse: 1.27872	valid_1's rmse: 1.329
# [450]	training's rmse: 1.1966	valid_1's rmse: 1.28667
# [600]	training's rmse: 1.14013	valid_1's rmse: 1.26929
# [750]	training's rmse: 1.10132	valid_1's rmse: 1.26142
# [900]	training's rmse: 1.07045	valid_1's rmse: 1.25794
# [1050]	training's rmse: 1.04786	valid_1's rmse: 1.2562
# [1200]	training's rmse: 1.02764	valid_1's rmse: 1.2552
# Early stopping, best iteration is:
# [1177]	training's rmse: 1.03089	valid_1's rmse: 1.25503
# Model training done in 31.847198963165283 seconds.
# Fold error 1.2550340444772121
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42534	valid_1's rmse: 1.46771
# [300]	training's rmse: 1.27414	valid_1's rmse: 1.35797
# [450]	training's rmse: 1.19153	valid_1's rmse: 1.31437
# [600]	training's rmse: 1.13432	valid_1's rmse: 1.29375
# [750]	training's rmse: 1.09389	valid_1's rmse: 1.28665
# [900]	training's rmse: 1.06283	valid_1's rmse: 1.28209
# [1050]	training's rmse: 1.04017	valid_1's rmse: 1.2802
# [1200]	training's rmse: 1.02111	valid_1's rmse: 1.2784
# [1350]	training's rmse: 1.00475	valid_1's rmse: 1.27779
# [1500]	training's rmse: 0.987327	valid_1's rmse: 1.27616
# [1650]	training's rmse: 0.971153	valid_1's rmse: 1.27485
# [1800]	training's rmse: 0.955456	valid_1's rmse: 1.27405
# Early stopping, best iteration is:
# [1791]	training's rmse: 0.956186	valid_1's rmse: 1.27398
# Model training done in 40.786046266555786 seconds.
# Fold error 1.2739793886518544
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41458	valid_1's rmse: 1.51538
# [300]	training's rmse: 1.26057	valid_1's rmse: 1.4154
# [450]	training's rmse: 1.17575	valid_1's rmse: 1.37958
# [600]	training's rmse: 1.11693	valid_1's rmse: 1.36632
# [750]	training's rmse: 1.07829	valid_1's rmse: 1.36251
# Early stopping, best iteration is:
# [796]	training's rmse: 1.06836	valid_1's rmse: 1.3616
# Model training done in 24.138342142105103 seconds.
# Fold error 1.3615997850852721
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42081	valid_1's rmse: 1.4565
# [300]	training's rmse: 1.26542	valid_1's rmse: 1.36362
# [450]	training's rmse: 1.17991	valid_1's rmse: 1.33416
# [600]	training's rmse: 1.12328	valid_1's rmse: 1.32528
# [750]	training's rmse: 1.0838	valid_1's rmse: 1.32334
# Early stopping, best iteration is:
# [732]	training's rmse: 1.08801	valid_1's rmse: 1.32329
# Model training done in 22.369877338409424 seconds.
# Fold error 1.3232851554322616
# Total error 1.33730987201
# Total std 0.04672
# Fitting big fold 3 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4026	valid_1's rmse: 1.49731
# [300]	training's rmse: 1.23942	valid_1's rmse: 1.40989
# [450]	training's rmse: 1.14849	valid_1's rmse: 1.37929
# [600]	training's rmse: 1.08689	valid_1's rmse: 1.36808
# [750]	training's rmse: 1.04443	valid_1's rmse: 1.36392
# [900]	training's rmse: 1.01001	valid_1's rmse: 1.36246
# [1050]	training's rmse: 0.984093	valid_1's rmse: 1.36193
# Early stopping, best iteration is:
# [1043]	training's rmse: 0.985182	valid_1's rmse: 1.3619
# Model training done in 20.192933320999146 seconds.
# Fold error 1.3618972529945688
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42428	valid_1's rmse: 1.4626
# [300]	training's rmse: 1.2712	valid_1's rmse: 1.36726
# [450]	training's rmse: 1.18704	valid_1's rmse: 1.33038
# [600]	training's rmse: 1.13095	valid_1's rmse: 1.315
# [750]	training's rmse: 1.09155	valid_1's rmse: 1.31008
# [900]	training's rmse: 1.06056	valid_1's rmse: 1.30648
# [1050]	training's rmse: 1.03701	valid_1's rmse: 1.30554
# Early stopping, best iteration is:
# [1098]	training's rmse: 1.03063	valid_1's rmse: 1.30483
# Model training done in 32.6405303478241 seconds.
# Fold error 1.3048253328189026
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42232	valid_1's rmse: 1.46743
# [300]	training's rmse: 1.26767	valid_1's rmse: 1.37744
# [450]	training's rmse: 1.18277	valid_1's rmse: 1.34822
# [600]	training's rmse: 1.12443	valid_1's rmse: 1.34034
# [750]	training's rmse: 1.08484	valid_1's rmse: 1.3373
# [900]	training's rmse: 1.05394	valid_1's rmse: 1.33755
# Early stopping, best iteration is:
# [818]	training's rmse: 1.07002	valid_1's rmse: 1.33702
# Model training done in 25.68719792366028 seconds.
# Fold error 1.3370187848901829
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41757	valid_1's rmse: 1.50252
# [300]	training's rmse: 1.26472	valid_1's rmse: 1.39823
# [450]	training's rmse: 1.18226	valid_1's rmse: 1.35905
# [600]	training's rmse: 1.12427	valid_1's rmse: 1.34221
# [750]	training's rmse: 1.08577	valid_1's rmse: 1.33468
# [900]	training's rmse: 1.05545	valid_1's rmse: 1.33165
# Early stopping, best iteration is:
# [936]	training's rmse: 1.04997	valid_1's rmse: 1.3314
# Model training done in 26.08022952079773 seconds.
# Fold error 1.3313976116050064
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41782	valid_1's rmse: 1.48205
# [300]	training's rmse: 1.26169	valid_1's rmse: 1.38883
# [450]	training's rmse: 1.17589	valid_1's rmse: 1.3557
# [600]	training's rmse: 1.11545	valid_1's rmse: 1.34279
# [750]	training's rmse: 1.0747	valid_1's rmse: 1.33848
# [900]	training's rmse: 1.04226	valid_1's rmse: 1.33659
# [1050]	training's rmse: 1.01876	valid_1's rmse: 1.33608
# Early stopping, best iteration is:
# [1017]	training's rmse: 1.02359	valid_1's rmse: 1.33597
# Model training done in 27.16576313972473 seconds.
# Fold error 1.3359715172514177
# Total error 1.34309285242
# Total std 0.01816
# Fitting big fold 4 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40973	valid_1's rmse: 1.48113
# [300]	training's rmse: 1.24481	valid_1's rmse: 1.38786
# [450]	training's rmse: 1.15239	valid_1's rmse: 1.35764
# [600]	training's rmse: 1.08881	valid_1's rmse: 1.3462
# [750]	training's rmse: 1.04341	valid_1's rmse: 1.34341
# [900]	training's rmse: 1.00741	valid_1's rmse: 1.34364
# Early stopping, best iteration is:
# [838]	training's rmse: 1.02039	valid_1's rmse: 1.34295
# Model training done in 18.41076135635376 seconds.
# Fold error 1.3429526129449374
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42418	valid_1's rmse: 1.4675
# [300]	training's rmse: 1.27122	valid_1's rmse: 1.37728
# [450]	training's rmse: 1.18757	valid_1's rmse: 1.34598
# [600]	training's rmse: 1.1304	valid_1's rmse: 1.33698
# [750]	training's rmse: 1.09069	valid_1's rmse: 1.33432
# [900]	training's rmse: 1.06017	valid_1's rmse: 1.33379
# Early stopping, best iteration is:
# [873]	training's rmse: 1.06543	valid_1's rmse: 1.33342
# Model training done in 27.487510919570923 seconds.
# Fold error 1.3334152160567616
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41821	valid_1's rmse: 1.50433
# [300]	training's rmse: 1.26393	valid_1's rmse: 1.41525
# [450]	training's rmse: 1.17903	valid_1's rmse: 1.38244
# [600]	training's rmse: 1.12234	valid_1's rmse: 1.36989
# [750]	training's rmse: 1.08351	valid_1's rmse: 1.36563
# [900]	training's rmse: 1.05413	valid_1's rmse: 1.36423
# Early stopping, best iteration is:
# [888]	training's rmse: 1.05628	valid_1's rmse: 1.36391
# Model training done in 27.14653468132019 seconds.
# Fold error 1.3639059543979175
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41781	valid_1's rmse: 1.5013
# [300]	training's rmse: 1.26281	valid_1's rmse: 1.40838
# [450]	training's rmse: 1.17792	valid_1's rmse: 1.3739
# [600]	training's rmse: 1.12033	valid_1's rmse: 1.35866
# [750]	training's rmse: 1.08085	valid_1's rmse: 1.35396
# [900]	training's rmse: 1.05062	valid_1's rmse: 1.35239
# Early stopping, best iteration is:
# [895]	training's rmse: 1.05161	valid_1's rmse: 1.35234
# Model training done in 25.434260845184326 seconds.
# Fold error 1.3523391290145441
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41861	valid_1's rmse: 1.48538
# [300]	training's rmse: 1.26442	valid_1's rmse: 1.38611
# [450]	training's rmse: 1.1803	valid_1's rmse: 1.34869
# [600]	training's rmse: 1.12233	valid_1's rmse: 1.33255
# [750]	training's rmse: 1.08333	valid_1's rmse: 1.32734
# [900]	training's rmse: 1.05306	valid_1's rmse: 1.32549
# [1050]	training's rmse: 1.03038	valid_1's rmse: 1.32502
# Early stopping, best iteration is:
# [981]	training's rmse: 1.04041	valid_1's rmse: 1.32488
# Model training done in 25.803292751312256 seconds.
# Fold error 1.3248753457408686
# Total error 1.34266307465
# Total std 0.01374
# Fitting big fold 5 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40257	valid_1's rmse: 1.5057
# [300]	training's rmse: 1.24048	valid_1's rmse: 1.41066
# [450]	training's rmse: 1.14862	valid_1's rmse: 1.37432
# [600]	training's rmse: 1.0852	valid_1's rmse: 1.35987
# [750]	training's rmse: 1.04066	valid_1's rmse: 1.35407
# [900]	training's rmse: 1.00711	valid_1's rmse: 1.35145
# [1050]	training's rmse: 0.982347	valid_1's rmse: 1.35082
# [1200]	training's rmse: 0.959523	valid_1's rmse: 1.35056
# Early stopping, best iteration is:
# [1132]	training's rmse: 0.969112	valid_1's rmse: 1.35036
# Model training done in 28.20598316192627 seconds.
# Fold error 1.3503603048241388
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4227	valid_1's rmse: 1.47583
# [300]	training's rmse: 1.26972	valid_1's rmse: 1.38942
# [450]	training's rmse: 1.18679	valid_1's rmse: 1.36066
# [600]	training's rmse: 1.13077	valid_1's rmse: 1.3486
# [750]	training's rmse: 1.09272	valid_1's rmse: 1.34445
# [900]	training's rmse: 1.06213	valid_1's rmse: 1.34364
# Early stopping, best iteration is:
# [937]	training's rmse: 1.05657	valid_1's rmse: 1.34338
# Model training done in 28.100200653076172 seconds.
# Fold error 1.3433813906566152
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42066	valid_1's rmse: 1.49407
# [300]	training's rmse: 1.26841	valid_1's rmse: 1.39357
# [450]	training's rmse: 1.18502	valid_1's rmse: 1.35791
# [600]	training's rmse: 1.12914	valid_1's rmse: 1.34264
# [750]	training's rmse: 1.09043	valid_1's rmse: 1.33645
# [900]	training's rmse: 1.06004	valid_1's rmse: 1.33324
# Early stopping, best iteration is:
# [921]	training's rmse: 1.05659	valid_1's rmse: 1.33307
# Model training done in 27.034981966018677 seconds.
# Fold error 1.333068158402109
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42375	valid_1's rmse: 1.4568
# [300]	training's rmse: 1.26784	valid_1's rmse: 1.36582
# [450]	training's rmse: 1.18284	valid_1's rmse: 1.33496
# [600]	training's rmse: 1.1247	valid_1's rmse: 1.32375
# [750]	training's rmse: 1.08411	valid_1's rmse: 1.32053
# [900]	training's rmse: 1.05311	valid_1's rmse: 1.31952
# Early stopping, best iteration is:
# [846]	training's rmse: 1.06329	valid_1's rmse: 1.31932
# Model training done in 27.242491960525513 seconds.
# Fold error 1.319324332268958
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41825	valid_1's rmse: 1.48494
# [300]	training's rmse: 1.26186	valid_1's rmse: 1.39351
# [450]	training's rmse: 1.17564	valid_1's rmse: 1.36048
# [600]	training's rmse: 1.11623	valid_1's rmse: 1.3479
# [750]	training's rmse: 1.07411	valid_1's rmse: 1.34366
# [900]	training's rmse: 1.04126	valid_1's rmse: 1.34173
# [1050]	training's rmse: 1.01642	valid_1's rmse: 1.34115
# [1200]	training's rmse: 0.994998	valid_1's rmse: 1.34047
# [1350]	training's rmse: 0.978238	valid_1's rmse: 1.34031
# [1500]	training's rmse: 0.959466	valid_1's rmse: 1.33976
# [1650]	training's rmse: 0.942651	valid_1's rmse: 1.33923
# [1800]	training's rmse: 0.926777	valid_1's rmse: 1.33885
# Early stopping, best iteration is:
# [1788]	training's rmse: 0.927932	valid_1's rmse: 1.33877
# Model training done in 38.74387240409851 seconds.
# Fold error 1.3387662368304756
# Total error 1.34020174441
# Total std 0.01049
# Fitting big fold 6 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40544	valid_1's rmse: 1.48246
# [300]	training's rmse: 1.23949	valid_1's rmse: 1.39218
# [450]	training's rmse: 1.14529	valid_1's rmse: 1.36049
# [600]	training's rmse: 1.07963	valid_1's rmse: 1.34838
# [750]	training's rmse: 1.03455	valid_1's rmse: 1.34463
# [900]	training's rmse: 1.00146	valid_1's rmse: 1.34374
# Early stopping, best iteration is:
# [819]	training's rmse: 1.01803	valid_1's rmse: 1.34359
# Model training done in 17.293269395828247 seconds.
# Fold error 1.3435944146575804
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42353	valid_1's rmse: 1.50208
# [300]	training's rmse: 1.27462	valid_1's rmse: 1.3857
# [450]	training's rmse: 1.19405	valid_1's rmse: 1.33958
# [600]	training's rmse: 1.13902	valid_1's rmse: 1.31839
# [750]	training's rmse: 1.10093	valid_1's rmse: 1.30831
# [900]	training's rmse: 1.07091	valid_1's rmse: 1.30439
# [1050]	training's rmse: 1.04873	valid_1's rmse: 1.30282
# [1200]	training's rmse: 1.02797	valid_1's rmse: 1.30201
# Early stopping, best iteration is:
# [1234]	training's rmse: 1.02428	valid_1's rmse: 1.30176
# Model training done in 33.71351504325867 seconds.
# Fold error 1.301764922413907
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42361	valid_1's rmse: 1.46873
# [300]	training's rmse: 1.27172	valid_1's rmse: 1.36953
# [450]	training's rmse: 1.18859	valid_1's rmse: 1.33332
# [600]	training's rmse: 1.13206	valid_1's rmse: 1.31868
# [750]	training's rmse: 1.0937	valid_1's rmse: 1.31247
# [900]	training's rmse: 1.06314	valid_1's rmse: 1.30985
# [1050]	training's rmse: 1.04175	valid_1's rmse: 1.30897
# [1200]	training's rmse: 1.02248	valid_1's rmse: 1.3091
# Early stopping, best iteration is:
# [1131]	training's rmse: 1.03131	valid_1's rmse: 1.30873
# Model training done in 30.003745794296265 seconds.
# Fold error 1.3087294094043502
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41973	valid_1's rmse: 1.48114
# [300]	training's rmse: 1.26466	valid_1's rmse: 1.39713
# [450]	training's rmse: 1.17984	valid_1's rmse: 1.36786
# [600]	training's rmse: 1.12179	valid_1's rmse: 1.35807
# [750]	training's rmse: 1.08031	valid_1's rmse: 1.3544
# [900]	training's rmse: 1.04832	valid_1's rmse: 1.35225
# [1050]	training's rmse: 1.02484	valid_1's rmse: 1.3526
# Early stopping, best iteration is:
# [966]	training's rmse: 1.03717	valid_1's rmse: 1.35192
# Model training done in 27.821840524673462 seconds.
# Fold error 1.3519209064989284
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41534	valid_1's rmse: 1.50014
# [300]	training's rmse: 1.25963	valid_1's rmse: 1.41007
# [450]	training's rmse: 1.17468	valid_1's rmse: 1.37574
# [600]	training's rmse: 1.11684	valid_1's rmse: 1.36266
# [750]	training's rmse: 1.07832	valid_1's rmse: 1.35801
# [900]	training's rmse: 1.04847	valid_1's rmse: 1.35622
# [1050]	training's rmse: 1.02628	valid_1's rmse: 1.35507
# Early stopping, best iteration is:
# [1040]	training's rmse: 1.02795	valid_1's rmse: 1.35496
# Model training done in 26.016578912734985 seconds.
# Fold error 1.3549600654659104
# Total error 1.33868884335
# Total std 0.02242
# Fitting big fold 7 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41765	valid_1's rmse: 1.46329
# [300]	training's rmse: 1.2515	valid_1's rmse: 1.3706
# [450]	training's rmse: 1.15884	valid_1's rmse: 1.33889
# [600]	training's rmse: 1.09437	valid_1's rmse: 1.32672
# [750]	training's rmse: 1.04823	valid_1's rmse: 1.32332
# [900]	training's rmse: 1.01353	valid_1's rmse: 1.32279
# Early stopping, best iteration is:
# [859]	training's rmse: 1.02182	valid_1's rmse: 1.32242
# Model training done in 18.99014973640442 seconds.
# Fold error 1.322425000803234
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41818	valid_1's rmse: 1.51031
# [300]	training's rmse: 1.26524	valid_1's rmse: 1.42391
# [450]	training's rmse: 1.18277	valid_1's rmse: 1.39436
# [600]	training's rmse: 1.12637	valid_1's rmse: 1.38267
# [750]	training's rmse: 1.08817	valid_1's rmse: 1.37893
# [900]	training's rmse: 1.05796	valid_1's rmse: 1.37757
# Early stopping, best iteration is:
# [909]	training's rmse: 1.05671	valid_1's rmse: 1.37754
# Model training done in 28.593042612075806 seconds.
# Fold error 1.377541690380956
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4152	valid_1's rmse: 1.53195
# [300]	training's rmse: 1.26287	valid_1's rmse: 1.43553
# [450]	training's rmse: 1.18052	valid_1's rmse: 1.40221
# [600]	training's rmse: 1.12419	valid_1's rmse: 1.38882
# [750]	training's rmse: 1.08639	valid_1's rmse: 1.38628
# Early stopping, best iteration is:
# [778]	training's rmse: 1.08044	valid_1's rmse: 1.3859
# Model training done in 24.368432998657227 seconds.
# Fold error 1.385897733621293
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41631	valid_1's rmse: 1.507
# [300]	training's rmse: 1.26291	valid_1's rmse: 1.40652
# [450]	training's rmse: 1.17874	valid_1's rmse: 1.36833
# [600]	training's rmse: 1.12242	valid_1's rmse: 1.353
# [750]	training's rmse: 1.08471	valid_1's rmse: 1.34696
# [900]	training's rmse: 1.05493	valid_1's rmse: 1.34503
# [1050]	training's rmse: 1.03148	valid_1's rmse: 1.34484
# Early stopping, best iteration is:
# [959]	training's rmse: 1.04501	valid_1's rmse: 1.34462
# Model training done in 26.636894941329956 seconds.
# Fold error 1.344621089249765
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42284	valid_1's rmse: 1.47123
# [300]	training's rmse: 1.2675	valid_1's rmse: 1.37553
# [450]	training's rmse: 1.18208	valid_1's rmse: 1.33865
# [600]	training's rmse: 1.12293	valid_1's rmse: 1.32207
# [750]	training's rmse: 1.08362	valid_1's rmse: 1.31541
# [900]	training's rmse: 1.05254	valid_1's rmse: 1.31218
# [1050]	training's rmse: 1.02877	valid_1's rmse: 1.31043
# [1200]	training's rmse: 1.00742	valid_1's rmse: 1.30977
# Early stopping, best iteration is:
# [1197]	training's rmse: 1.00786	valid_1's rmse: 1.30973
# Model training done in 33.930585861206055 seconds.
# Fold error 1.3097271855313164
# Total error 1.33780354266
# Total std 0.0298
# Fitting big fold 8 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4154	valid_1's rmse: 1.48121
# [300]	training's rmse: 1.25296	valid_1's rmse: 1.38569
# [450]	training's rmse: 1.16042	valid_1's rmse: 1.3497
# [600]	training's rmse: 1.09631	valid_1's rmse: 1.33455
# [750]	training's rmse: 1.0514	valid_1's rmse: 1.32964
# [900]	training's rmse: 1.0182	valid_1's rmse: 1.32816
# [1050]	training's rmse: 0.993424	valid_1's rmse: 1.32786
# Early stopping, best iteration is:
# [1059]	training's rmse: 0.992101	valid_1's rmse: 1.32775
# Model training done in 22.88622260093689 seconds.
# Fold error 1.3277494763218556
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42271	valid_1's rmse: 1.46803
# [300]	training's rmse: 1.27026	valid_1's rmse: 1.37716
# [450]	training's rmse: 1.18673	valid_1's rmse: 1.34486
# [600]	training's rmse: 1.12941	valid_1's rmse: 1.33243
# [750]	training's rmse: 1.09067	valid_1's rmse: 1.32911
# [900]	training's rmse: 1.06017	valid_1's rmse: 1.32903
# Early stopping, best iteration is:
# [802]	training's rmse: 1.0793	valid_1's rmse: 1.32888
# Model training done in 29.75667977333069 seconds.
# Fold error 1.3288756707934586
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41507	valid_1's rmse: 1.51787
# [300]	training's rmse: 1.25952	valid_1's rmse: 1.43649
# [450]	training's rmse: 1.17562	valid_1's rmse: 1.40957
# [600]	training's rmse: 1.11861	valid_1's rmse: 1.40071
# [750]	training's rmse: 1.08062	valid_1's rmse: 1.39637
# [900]	training's rmse: 1.05029	valid_1's rmse: 1.39615
# Early stopping, best iteration is:
# [873]	training's rmse: 1.05534	valid_1's rmse: 1.39585
# Model training done in 27.582966804504395 seconds.
# Fold error 1.3958481021803664
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41792	valid_1's rmse: 1.49218
# [300]	training's rmse: 1.26452	valid_1's rmse: 1.39547
# [450]	training's rmse: 1.18043	valid_1's rmse: 1.35965
# [600]	training's rmse: 1.12275	valid_1's rmse: 1.34446
# [750]	training's rmse: 1.08324	valid_1's rmse: 1.3389
# [900]	training's rmse: 1.05367	valid_1's rmse: 1.3359
# [1050]	training's rmse: 1.03181	valid_1's rmse: 1.33528
# [1200]	training's rmse: 1.01268	valid_1's rmse: 1.33424
# Early stopping, best iteration is:
# [1158]	training's rmse: 1.01816	valid_1's rmse: 1.33404
# Model training done in 29.075162649154663 seconds.
# Fold error 1.3340396634575116
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41807	valid_1's rmse: 1.48768
# [300]	training's rmse: 1.26409	valid_1's rmse: 1.39171
# [450]	training's rmse: 1.17896	valid_1's rmse: 1.35876
# [600]	training's rmse: 1.11964	valid_1's rmse: 1.34544
# [750]	training's rmse: 1.07832	valid_1's rmse: 1.34196
# [900]	training's rmse: 1.04694	valid_1's rmse: 1.3403
# Early stopping, best iteration is:
# [929]	training's rmse: 1.0422	valid_1's rmse: 1.3402
# Model training done in 25.28085970878601 seconds.
# Fold error 1.340197533690659
# Total error 1.34008526514
# Total std 0.02563
# Fitting big fold 9 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40924	valid_1's rmse: 1.49993
# [300]	training's rmse: 1.25171	valid_1's rmse: 1.39891
# [450]	training's rmse: 1.16074	valid_1's rmse: 1.36123
# [600]	training's rmse: 1.09786	valid_1's rmse: 1.34421
# [750]	training's rmse: 1.05382	valid_1's rmse: 1.33785
# [900]	training's rmse: 1.01894	valid_1's rmse: 1.33453
# [1050]	training's rmse: 0.993508	valid_1's rmse: 1.33391
# [1200]	training's rmse: 0.971806	valid_1's rmse: 1.334
# Early stopping, best iteration is:
# [1101]	training's rmse: 0.985825	valid_1's rmse: 1.3337
# Model training done in 21.9822359085083 seconds.
# Fold error 1.3337012341776695
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4259	valid_1's rmse: 1.44334
# [300]	training's rmse: 1.27492	valid_1's rmse: 1.33435
# [450]	training's rmse: 1.19234	valid_1's rmse: 1.29282
# [600]	training's rmse: 1.13599	valid_1's rmse: 1.27505
# [750]	training's rmse: 1.09811	valid_1's rmse: 1.26738
# [900]	training's rmse: 1.0687	valid_1's rmse: 1.26418
# [1050]	training's rmse: 1.0464	valid_1's rmse: 1.26314
# [1200]	training's rmse: 1.02681	valid_1's rmse: 1.26246
# [1350]	training's rmse: 1.00926	valid_1's rmse: 1.2614
# [1500]	training's rmse: 0.990964	valid_1's rmse: 1.26038
# Early stopping, best iteration is:
# [1479]	training's rmse: 0.993693	valid_1's rmse: 1.26015
# Model training done in 36.696633100509644 seconds.
# Fold error 1.2601478932370398
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41652	valid_1's rmse: 1.50955
# [300]	training's rmse: 1.26134	valid_1's rmse: 1.42351
# [450]	training's rmse: 1.17616	valid_1's rmse: 1.39478
# [600]	training's rmse: 1.11798	valid_1's rmse: 1.38469
# [750]	training's rmse: 1.0785	valid_1's rmse: 1.38213
# [900]	training's rmse: 1.04769	valid_1's rmse: 1.37991
# [1050]	training's rmse: 1.02508	valid_1's rmse: 1.37954
# Early stopping, best iteration is:
# [1085]	training's rmse: 1.01996	valid_1's rmse: 1.3793
# Model training done in 29.985998153686523 seconds.
# Fold error 1.3792969019216883
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42205	valid_1's rmse: 1.47103
# [300]	training's rmse: 1.26602	valid_1's rmse: 1.38679
# [450]	training's rmse: 1.18151	valid_1's rmse: 1.35828
# [600]	training's rmse: 1.12295	valid_1's rmse: 1.34844
# [750]	training's rmse: 1.08318	valid_1's rmse: 1.34596
# [900]	training's rmse: 1.05151	valid_1's rmse: 1.34527
# Early stopping, best iteration is:
# [842]	training's rmse: 1.06293	valid_1's rmse: 1.34503
# Model training done in 25.474499225616455 seconds.
# Fold error 1.3450272925294953
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41653	valid_1's rmse: 1.48326
# [300]	training's rmse: 1.25933	valid_1's rmse: 1.39641
# [450]	training's rmse: 1.17349	valid_1's rmse: 1.36509
# [600]	training's rmse: 1.11502	valid_1's rmse: 1.35382
# [750]	training's rmse: 1.0744	valid_1's rmse: 1.35001
# [900]	training's rmse: 1.04355	valid_1's rmse: 1.349
# Early stopping, best iteration is:
# [944]	training's rmse: 1.03609	valid_1's rmse: 1.34888
# Model training done in 27.530882120132446 seconds.
# Fold error 1.3488817849361976
# Total error 1.3372300366
# Total std 0.03962
# Fitting big fold 10 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40297	valid_1's rmse: 1.49048
# [300]	training's rmse: 1.23654	valid_1's rmse: 1.39949
# [450]	training's rmse: 1.14326	valid_1's rmse: 1.36795
# [600]	training's rmse: 1.07829	valid_1's rmse: 1.35622
# [750]	training's rmse: 1.03236	valid_1's rmse: 1.35218
# [900]	training's rmse: 0.998322	valid_1's rmse: 1.35121
# Early stopping, best iteration is:
# [845]	training's rmse: 1.00991	valid_1's rmse: 1.35102
# Model training done in 21.92528462409973 seconds.
# Fold error 1.351022391037449
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42168	valid_1's rmse: 1.48081
# [300]	training's rmse: 1.26965	valid_1's rmse: 1.38956
# [450]	training's rmse: 1.18724	valid_1's rmse: 1.35627
# [600]	training's rmse: 1.13058	valid_1's rmse: 1.34314
# [750]	training's rmse: 1.09199	valid_1's rmse: 1.33805
# [900]	training's rmse: 1.06172	valid_1's rmse: 1.33653
# Early stopping, best iteration is:
# [884]	training's rmse: 1.0648	valid_1's rmse: 1.3362
# Model training done in 29.71160387992859 seconds.
# Fold error 1.3361971693026369
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42473	valid_1's rmse: 1.47144
# [300]	training's rmse: 1.27245	valid_1's rmse: 1.3669
# [450]	training's rmse: 1.18903	valid_1's rmse: 1.32776
# [600]	training's rmse: 1.13289	valid_1's rmse: 1.31161
# [750]	training's rmse: 1.09515	valid_1's rmse: 1.30677
# [900]	training's rmse: 1.065	valid_1's rmse: 1.30493
# [1050]	training's rmse: 1.04324	valid_1's rmse: 1.30445
# [1200]	training's rmse: 1.02329	valid_1's rmse: 1.30468
# Early stopping, best iteration is:
# [1158]	training's rmse: 1.0287	valid_1's rmse: 1.30405
# Model training done in 31.17850613594055 seconds.
# Fold error 1.3040471376983773
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41778	valid_1's rmse: 1.4973
# [300]	training's rmse: 1.26345	valid_1's rmse: 1.39812
# [450]	training's rmse: 1.17889	valid_1's rmse: 1.36374
# [600]	training's rmse: 1.12156	valid_1's rmse: 1.35018
# [750]	training's rmse: 1.08246	valid_1's rmse: 1.34436
# [900]	training's rmse: 1.05266	valid_1's rmse: 1.34335
# [1050]	training's rmse: 1.03018	valid_1's rmse: 1.34301
# Early stopping, best iteration is:
# [955]	training's rmse: 1.04406	valid_1's rmse: 1.34291
# Model training done in 27.27300190925598 seconds.
# Fold error 1.342914598784666
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42055	valid_1's rmse: 1.47276
# [300]	training's rmse: 1.26546	valid_1's rmse: 1.37712
# [450]	training's rmse: 1.18155	valid_1's rmse: 1.34257
# [600]	training's rmse: 1.1237	valid_1's rmse: 1.32903
# [750]	training's rmse: 1.08224	valid_1's rmse: 1.32525
# [900]	training's rmse: 1.05061	valid_1's rmse: 1.32325
# [1050]	training's rmse: 1.02741	valid_1's rmse: 1.32285
# Early stopping, best iteration is:
# [1045]	training's rmse: 1.02811	valid_1's rmse: 1.32271
# Model training done in 34.930702686309814 seconds.
# Fold error 1.3227133049669528
# Total error 1.33664968207
# Total std 0.01652
# Fitting big fold 11 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41733	valid_1's rmse: 1.48132
# [300]	training's rmse: 1.25402	valid_1's rmse: 1.39042
# [450]	training's rmse: 1.16155	valid_1's rmse: 1.35839
# [600]	training's rmse: 1.09806	valid_1's rmse: 1.34543
# [750]	training's rmse: 1.05314	valid_1's rmse: 1.34154
# [900]	training's rmse: 1.0182	valid_1's rmse: 1.34021
# [1050]	training's rmse: 0.989179	valid_1's rmse: 1.3405
# Early stopping, best iteration is:
# [1003]	training's rmse: 0.9976	valid_1's rmse: 1.34004
# Model training done in 19.55488085746765 seconds.
# Fold error 1.340037040941307
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42583	valid_1's rmse: 1.45808
# [300]	training's rmse: 1.27465	valid_1's rmse: 1.35439
# [450]	training's rmse: 1.19258	valid_1's rmse: 1.3178
# [600]	training's rmse: 1.1354	valid_1's rmse: 1.30395
# [750]	training's rmse: 1.0961	valid_1's rmse: 1.29793
# [900]	training's rmse: 1.06715	valid_1's rmse: 1.29534
# [1050]	training's rmse: 1.04553	valid_1's rmse: 1.2944
# [1200]	training's rmse: 1.02577	valid_1's rmse: 1.29426
# Early stopping, best iteration is:
# [1189]	training's rmse: 1.02681	valid_1's rmse: 1.29418
# Model training done in 31.835036039352417 seconds.
# Fold error 1.2941777628101574
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41635	valid_1's rmse: 1.51365
# [300]	training's rmse: 1.26331	valid_1's rmse: 1.42015
# [450]	training's rmse: 1.18157	valid_1's rmse: 1.3849
# [600]	training's rmse: 1.12465	valid_1's rmse: 1.37273
# [750]	training's rmse: 1.08621	valid_1's rmse: 1.3678
# [900]	training's rmse: 1.0561	valid_1's rmse: 1.3648
# Early stopping, best iteration is:
# [897]	training's rmse: 1.05663	valid_1's rmse: 1.36478
# Model training done in 26.9540593624115 seconds.
# Fold error 1.3647752830889666
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42	valid_1's rmse: 1.4806
# [300]	training's rmse: 1.26487	valid_1's rmse: 1.39307
# [450]	training's rmse: 1.18033	valid_1's rmse: 1.36156
# [600]	training's rmse: 1.12334	valid_1's rmse: 1.34681
# [750]	training's rmse: 1.08396	valid_1's rmse: 1.341
# [900]	training's rmse: 1.05312	valid_1's rmse: 1.3401
# Early stopping, best iteration is:
# [839]	training's rmse: 1.06428	valid_1's rmse: 1.33988
# Model training done in 25.91568160057068 seconds.
# Fold error 1.3398822779385462
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41148	valid_1's rmse: 1.51118
# [300]	training's rmse: 1.25527	valid_1's rmse: 1.42082
# [450]	training's rmse: 1.16887	valid_1's rmse: 1.39097
# [600]	training's rmse: 1.1097	valid_1's rmse: 1.38
# [750]	training's rmse: 1.06786	valid_1's rmse: 1.37614
# [900]	training's rmse: 1.03681	valid_1's rmse: 1.37467
# [1050]	training's rmse: 1.01318	valid_1's rmse: 1.37378
# Early stopping, best iteration is:
# [1003]	training's rmse: 1.02057	valid_1's rmse: 1.37359
# Model training done in 26.33697247505188 seconds.
# Fold error 1.3735915606297937
# Total error 1.34526702924
# Total std 0.02761
# Fitting big fold 12 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41292	valid_1's rmse: 1.481
# [300]	training's rmse: 1.24822	valid_1's rmse: 1.3863
# [450]	training's rmse: 1.15435	valid_1's rmse: 1.35261
# [600]	training's rmse: 1.09053	valid_1's rmse: 1.34031
# [750]	training's rmse: 1.04695	valid_1's rmse: 1.3377
# [900]	training's rmse: 1.01474	valid_1's rmse: 1.33747
# Early stopping, best iteration is:
# [819]	training's rmse: 1.03142	valid_1's rmse: 1.33711
# Model training done in 17.53450584411621 seconds.
# Fold error 1.337105017069384
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42441	valid_1's rmse: 1.46875
# [300]	training's rmse: 1.27163	valid_1's rmse: 1.37114
# [450]	training's rmse: 1.18915	valid_1's rmse: 1.33833
# [600]	training's rmse: 1.13164	valid_1's rmse: 1.32553
# [750]	training's rmse: 1.0933	valid_1's rmse: 1.32222
# Early stopping, best iteration is:
# [788]	training's rmse: 1.08494	valid_1's rmse: 1.32184
# Model training done in 25.441134691238403 seconds.
# Fold error 1.3218378318140256
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42003	valid_1's rmse: 1.51049
# [300]	training's rmse: 1.26681	valid_1's rmse: 1.41237
# [450]	training's rmse: 1.18344	valid_1's rmse: 1.37469
# [600]	training's rmse: 1.12693	valid_1's rmse: 1.35681
# [750]	training's rmse: 1.08818	valid_1's rmse: 1.34866
# [900]	training's rmse: 1.0572	valid_1's rmse: 1.34589
# [1050]	training's rmse: 1.03326	valid_1's rmse: 1.34514
# Early stopping, best iteration is:
# [1078]	training's rmse: 1.02937	valid_1's rmse: 1.34498
# Model training done in 29.161782264709473 seconds.
# Fold error 1.3449790243655666
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.418	valid_1's rmse: 1.48877
# [300]	training's rmse: 1.26342	valid_1's rmse: 1.39916
# [450]	training's rmse: 1.17877	valid_1's rmse: 1.36865
# [600]	training's rmse: 1.12126	valid_1's rmse: 1.3577
# [750]	training's rmse: 1.08169	valid_1's rmse: 1.3542
# [900]	training's rmse: 1.05109	valid_1's rmse: 1.35357
# Early stopping, best iteration is:
# [841]	training's rmse: 1.06251	valid_1's rmse: 1.35305
# Model training done in 28.833900213241577 seconds.
# Fold error 1.3530517105952145
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41467	valid_1's rmse: 1.49635
# [300]	training's rmse: 1.25703	valid_1's rmse: 1.4107
# [450]	training's rmse: 1.17264	valid_1's rmse: 1.38086
# [600]	training's rmse: 1.11546	valid_1's rmse: 1.37127
# [750]	training's rmse: 1.07554	valid_1's rmse: 1.36773
# [900]	training's rmse: 1.04376	valid_1's rmse: 1.36779
# Early stopping, best iteration is:
# [839]	training's rmse: 1.05527	valid_1's rmse: 1.36727
# Model training done in 25.020053386688232 seconds.
# Fold error 1.3672655098739592
# Total error 1.34526547476
# Total std 0.01523
# Fitting big fold 13 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4061	valid_1's rmse: 1.49277
# [300]	training's rmse: 1.23989	valid_1's rmse: 1.40218
# [450]	training's rmse: 1.14361	valid_1's rmse: 1.36951
# [600]	training's rmse: 1.07714	valid_1's rmse: 1.35669
# [750]	training's rmse: 1.02951	valid_1's rmse: 1.35296
# [900]	training's rmse: 0.993069	valid_1's rmse: 1.35245
# Early stopping, best iteration is:
# [934]	training's rmse: 0.986536	valid_1's rmse: 1.35233
# Model training done in 19.716687202453613 seconds.
# Fold error 1.352325775548359
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42505	valid_1's rmse: 1.45524
# [300]	training's rmse: 1.27261	valid_1's rmse: 1.34927
# [450]	training's rmse: 1.18939	valid_1's rmse: 1.30941
# [600]	training's rmse: 1.13234	valid_1's rmse: 1.29392
# [750]	training's rmse: 1.09441	valid_1's rmse: 1.28856
# [900]	training's rmse: 1.06489	valid_1's rmse: 1.28555
# [1050]	training's rmse: 1.04381	valid_1's rmse: 1.28539
# Early stopping, best iteration is:
# [981]	training's rmse: 1.05311	valid_1's rmse: 1.28456
# Model training done in 40.47624182701111 seconds.
# Fold error 1.284562563590464
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42284	valid_1's rmse: 1.46586
# [300]	training's rmse: 1.27064	valid_1's rmse: 1.36698
# [450]	training's rmse: 1.187	valid_1's rmse: 1.33101
# [600]	training's rmse: 1.13007	valid_1's rmse: 1.31828
# [750]	training's rmse: 1.09098	valid_1's rmse: 1.31332
# [900]	training's rmse: 1.06002	valid_1's rmse: 1.31136
# Early stopping, best iteration is:
# [942]	training's rmse: 1.05342	valid_1's rmse: 1.3113
# Model training done in 28.832369089126587 seconds.
# Fold error 1.3113002040339174
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41346	valid_1's rmse: 1.52426
# [300]	training's rmse: 1.25847	valid_1's rmse: 1.44456
# [450]	training's rmse: 1.17414	valid_1's rmse: 1.41792
# [600]	training's rmse: 1.11644	valid_1's rmse: 1.40899
# [750]	training's rmse: 1.07701	valid_1's rmse: 1.40633
# [900]	training's rmse: 1.04598	valid_1's rmse: 1.4061
# Early stopping, best iteration is:
# [845]	training's rmse: 1.05698	valid_1's rmse: 1.40567
# Model training done in 25.140506744384766 seconds.
# Fold error 1.4056748106320982
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41926	valid_1's rmse: 1.47856
# [300]	training's rmse: 1.2652	valid_1's rmse: 1.38118
# [450]	training's rmse: 1.18009	valid_1's rmse: 1.34757
# [600]	training's rmse: 1.12331	valid_1's rmse: 1.33403
# [750]	training's rmse: 1.08398	valid_1's rmse: 1.32968
# [900]	training's rmse: 1.05207	valid_1's rmse: 1.32808
# [1050]	training's rmse: 1.02807	valid_1's rmse: 1.32794
# [1200]	training's rmse: 1.00692	valid_1's rmse: 1.32778
# Early stopping, best iteration is:
# [1156]	training's rmse: 1.01285	valid_1's rmse: 1.32755
# Model training done in 28.911897659301758 seconds.
# Fold error 1.3275540175837879
# Total error 1.34453849656
# Total std 0.0411
# Fitting big fold 14 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40385	valid_1's rmse: 1.48918
# [300]	training's rmse: 1.23757	valid_1's rmse: 1.40295
# [450]	training's rmse: 1.14722	valid_1's rmse: 1.37228
# [600]	training's rmse: 1.08328	valid_1's rmse: 1.35986
# [750]	training's rmse: 1.03902	valid_1's rmse: 1.35497
# [900]	training's rmse: 1.00596	valid_1's rmse: 1.35348
# [1050]	training's rmse: 0.982845	valid_1's rmse: 1.35237
# [1200]	training's rmse: 0.961181	valid_1's rmse: 1.35235
# Early stopping, best iteration is:
# [1103]	training's rmse: 0.974918	valid_1's rmse: 1.35224
# Model training done in 21.594839096069336 seconds.
# Fold error 1.3522389667357424
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42389	valid_1's rmse: 1.47622
# [300]	training's rmse: 1.27411	valid_1's rmse: 1.37432
# [450]	training's rmse: 1.19206	valid_1's rmse: 1.33591
# [600]	training's rmse: 1.13626	valid_1's rmse: 1.32077
# [750]	training's rmse: 1.09819	valid_1's rmse: 1.31543
# [900]	training's rmse: 1.06786	valid_1's rmse: 1.31336
# [1050]	training's rmse: 1.04614	valid_1's rmse: 1.31336
# Early stopping, best iteration is:
# [1016]	training's rmse: 1.05107	valid_1's rmse: 1.31279
# Model training done in 30.160008668899536 seconds.
# Fold error 1.3127894038646282
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42419	valid_1's rmse: 1.47242
# [300]	training's rmse: 1.27199	valid_1's rmse: 1.36517
# [450]	training's rmse: 1.18846	valid_1's rmse: 1.32471
# [600]	training's rmse: 1.13138	valid_1's rmse: 1.30767
# [750]	training's rmse: 1.09157	valid_1's rmse: 1.30091
# [900]	training's rmse: 1.06001	valid_1's rmse: 1.29859
# [1050]	training's rmse: 1.03613	valid_1's rmse: 1.29677
# [1200]	training's rmse: 1.01572	valid_1's rmse: 1.29723
# Early stopping, best iteration is:
# [1138]	training's rmse: 1.02407	valid_1's rmse: 1.29654
# Model training done in 33.584739685058594 seconds.
# Fold error 1.2965448104819084
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42241	valid_1's rmse: 1.47341
# [300]	training's rmse: 1.26824	valid_1's rmse: 1.37841
# [450]	training's rmse: 1.18235	valid_1's rmse: 1.34564
# [600]	training's rmse: 1.12588	valid_1's rmse: 1.3314
# [750]	training's rmse: 1.08558	valid_1's rmse: 1.32662
# [900]	training's rmse: 1.05449	valid_1's rmse: 1.32553
# Early stopping, best iteration is:
# [843]	training's rmse: 1.06504	valid_1's rmse: 1.32497
# Model training done in 24.65306544303894 seconds.
# Fold error 1.3249671872107434
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41017	valid_1's rmse: 1.50967
# [300]	training's rmse: 1.25382	valid_1's rmse: 1.42051
# [450]	training's rmse: 1.16625	valid_1's rmse: 1.39174
# [600]	training's rmse: 1.10591	valid_1's rmse: 1.38313
# [750]	training's rmse: 1.06515	valid_1's rmse: 1.38145
# Early stopping, best iteration is:
# [797]	training's rmse: 1.05423	valid_1's rmse: 1.38125
# Model training done in 23.78848171234131 seconds.
# Fold error 1.3812489899954328
# Total error 1.34258496941
# Total std 0.03
# Fitting big fold 15 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41081	valid_1's rmse: 1.47982
# [300]	training's rmse: 1.24562	valid_1's rmse: 1.38614
# [450]	training's rmse: 1.15315	valid_1's rmse: 1.35305
# [600]	training's rmse: 1.08839	valid_1's rmse: 1.33987
# [750]	training's rmse: 1.04326	valid_1's rmse: 1.33571
# [900]	training's rmse: 1.00802	valid_1's rmse: 1.33391
# [1050]	training's rmse: 0.979854	valid_1's rmse: 1.33373
# [1200]	training's rmse: 0.954868	valid_1's rmse: 1.3337
# Early stopping, best iteration is:
# [1106]	training's rmse: 0.970143	valid_1's rmse: 1.33351
# Model training done in 21.85047674179077 seconds.
# Fold error 1.3335107213322477
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42076	valid_1's rmse: 1.50635
# [300]	training's rmse: 1.2692	valid_1's rmse: 1.40821
# [450]	training's rmse: 1.18621	valid_1's rmse: 1.37074
# [600]	training's rmse: 1.13022	valid_1's rmse: 1.35378
# [750]	training's rmse: 1.09292	valid_1's rmse: 1.34678
# [900]	training's rmse: 1.06266	valid_1's rmse: 1.34297
# Early stopping, best iteration is:
# [907]	training's rmse: 1.06166	valid_1's rmse: 1.34279
# Model training done in 27.470023155212402 seconds.
# Fold error 1.3427945065196987
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42741	valid_1's rmse: 1.434
# [300]	training's rmse: 1.27507	valid_1's rmse: 1.33272
# [450]	training's rmse: 1.19124	valid_1's rmse: 1.2987
# [600]	training's rmse: 1.13451	valid_1's rmse: 1.2878
# [750]	training's rmse: 1.0953	valid_1's rmse: 1.2855
# [900]	training's rmse: 1.0645	valid_1's rmse: 1.28535
# Early stopping, best iteration is:
# [839]	training's rmse: 1.07617	valid_1's rmse: 1.28476
# Model training done in 25.995315074920654 seconds.
# Fold error 1.284762350868022
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4169	valid_1's rmse: 1.49777
# [300]	training's rmse: 1.26132	valid_1's rmse: 1.40657
# [450]	training's rmse: 1.17715	valid_1's rmse: 1.37274
# [600]	training's rmse: 1.11918	valid_1's rmse: 1.35949
# [750]	training's rmse: 1.07935	valid_1's rmse: 1.35374
# [900]	training's rmse: 1.04823	valid_1's rmse: 1.35078
# [1050]	training's rmse: 1.02673	valid_1's rmse: 1.34888
# ...
# [450]	training's rmse: 1.14509	valid_1's rmse: 1.37925
# [600]	training's rmse: 1.08225	valid_1's rmse: 1.36562
# [750]	training's rmse: 1.03879	valid_1's rmse: 1.36067
# [900]	training's rmse: 1.00599	valid_1's rmse: 1.35909
# [1050]	training's rmse: 0.980928	valid_1's rmse: 1.35896
# Early stopping, best iteration is:
# [994]	training's rmse: 0.989272	valid_1's rmse: 1.35873
# Model training done in 19.417481422424316 seconds.
# Fold error 1.3587316505503721
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42269	valid_1's rmse: 1.47513
# [300]	training's rmse: 1.26962	valid_1's rmse: 1.38314
# [450]	training's rmse: 1.18638	valid_1's rmse: 1.34787
# [600]	training's rmse: 1.12913	valid_1's rmse: 1.3317
# [750]	training's rmse: 1.0902	valid_1's rmse: 1.32525
# [900]	training's rmse: 1.05948	valid_1's rmse: 1.32223
# [1050]	training's rmse: 1.03609	valid_1's rmse: 1.32238
# Early stopping, best iteration is:
# [966]	training's rmse: 1.04874	valid_1's rmse: 1.32202
# Model training done in 29.818406343460083 seconds.
# Fold error 1.3220237652129847
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42498	valid_1's rmse: 1.44313
# [300]	training's rmse: 1.27083	valid_1's rmse: 1.35472
# [450]	training's rmse: 1.18596	valid_1's rmse: 1.32671
# [600]	training's rmse: 1.127	valid_1's rmse: 1.3169
# [750]	training's rmse: 1.0866	valid_1's rmse: 1.31332
# [900]	training's rmse: 1.0553	valid_1's rmse: 1.31181
# Early stopping, best iteration is:
# [901]	training's rmse: 1.05518	valid_1's rmse: 1.31176
# Model training done in 27.594030618667603 seconds.
# Fold error 1.3117623476789106
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41941	valid_1's rmse: 1.49664
# [300]	training's rmse: 1.2668	valid_1's rmse: 1.40563
# [450]	training's rmse: 1.18345	valid_1's rmse: 1.37314
# [600]	training's rmse: 1.12658	valid_1's rmse: 1.35977
# [750]	training's rmse: 1.08683	valid_1's rmse: 1.35556
# [900]	training's rmse: 1.05685	valid_1's rmse: 1.35382
# [1050]	training's rmse: 1.03485	valid_1's rmse: 1.35352
# Early stopping, best iteration is:
# [1043]	training's rmse: 1.03583	valid_1's rmse: 1.35336
# Model training done in 28.640385389328003 seconds.
# Fold error 1.3533612975106462
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41765	valid_1's rmse: 1.48474
# [300]	training's rmse: 1.26206	valid_1's rmse: 1.39052
# [450]	training's rmse: 1.17743	valid_1's rmse: 1.35779
# [600]	training's rmse: 1.11941	valid_1's rmse: 1.34555
# [750]	training's rmse: 1.07946	valid_1's rmse: 1.34075
# [900]	training's rmse: 1.04799	valid_1's rmse: 1.33793
# [1050]	training's rmse: 1.02552	valid_1's rmse: 1.3374
# Early stopping, best iteration is:
# [1042]	training's rmse: 1.02651	valid_1's rmse: 1.33721
# Model training done in 27.966933727264404 seconds.
# Fold error 1.3372110693050931
# Total error 1.34379835726
# Total std 0.01789
# Fitting big fold 17 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40249	valid_1's rmse: 1.49576
# [300]	training's rmse: 1.2371	valid_1's rmse: 1.40667
# [450]	training's rmse: 1.14534	valid_1's rmse: 1.37613
# [600]	training's rmse: 1.08211	valid_1's rmse: 1.36351
# [750]	training's rmse: 1.037	valid_1's rmse: 1.36026
# [900]	training's rmse: 1.00205	valid_1's rmse: 1.35891
# Early stopping, best iteration is:
# [891]	training's rmse: 1.00403	valid_1's rmse: 1.35891
# Model training done in 18.82023787498474 seconds.
# Fold error 1.3589054024976972
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42073	valid_1's rmse: 1.48633
# [300]	training's rmse: 1.26806	valid_1's rmse: 1.39996
# [450]	training's rmse: 1.18512	valid_1's rmse: 1.36817
# [600]	training's rmse: 1.12817	valid_1's rmse: 1.35552
# [750]	training's rmse: 1.08953	valid_1's rmse: 1.34994
# [900]	training's rmse: 1.05901	valid_1's rmse: 1.34638
# [1050]	training's rmse: 1.03751	valid_1's rmse: 1.34594
# [1200]	training's rmse: 1.01819	valid_1's rmse: 1.34539
# Early stopping, best iteration is:
# [1166]	training's rmse: 1.02236	valid_1's rmse: 1.34515
# Model training done in 31.625399112701416 seconds.
# Fold error 1.3451456844439262
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42087	valid_1's rmse: 1.47854
# [300]	training's rmse: 1.26715	valid_1's rmse: 1.38714
# [450]	training's rmse: 1.1835	valid_1's rmse: 1.35456
# [600]	training's rmse: 1.12544	valid_1's rmse: 1.34218
# [750]	training's rmse: 1.08726	valid_1's rmse: 1.3377
# [900]	training's rmse: 1.05587	valid_1's rmse: 1.33666
# [1050]	training's rmse: 1.03324	valid_1's rmse: 1.33628
# [1200]	training's rmse: 1.01315	valid_1's rmse: 1.33542
# [1350]	training's rmse: 0.995862	valid_1's rmse: 1.3348
# Early stopping, best iteration is:
# [1315]	training's rmse: 1.00002	valid_1's rmse: 1.33452
# Model training done in 35.88422632217407 seconds.
# Fold error 1.3345156614648555
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41558	valid_1's rmse: 1.50871
# [300]	training's rmse: 1.26252	valid_1's rmse: 1.4072
# [450]	training's rmse: 1.17789	valid_1's rmse: 1.37047
# [600]	training's rmse: 1.12145	valid_1's rmse: 1.35563
# [750]	training's rmse: 1.08216	valid_1's rmse: 1.3506
# [900]	training's rmse: 1.05178	valid_1's rmse: 1.34816
# Early stopping, best iteration is:
# [889]	training's rmse: 1.05352	valid_1's rmse: 1.34809
# Model training done in 25.783071994781494 seconds.
# Fold error 1.3480922567322275
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4271	valid_1's rmse: 1.45758
# [300]	training's rmse: 1.2752	valid_1's rmse: 1.35412
# [450]	training's rmse: 1.19073	valid_1's rmse: 1.31736
# [600]	training's rmse: 1.13308	valid_1's rmse: 1.30323
# [750]	training's rmse: 1.09059	valid_1's rmse: 1.29949
# [900]	training's rmse: 1.0595	valid_1's rmse: 1.29828
# Early stopping, best iteration is:
# [869]	training's rmse: 1.06525	valid_1's rmse: 1.29806
# Model training done in 24.035375356674194 seconds.
# Fold error 1.2980646973750798
# Total error 1.34062868146
# Total std 0.02093
# Fitting big fold 18 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40801	valid_1's rmse: 1.49495
# [300]	training's rmse: 1.2465	valid_1's rmse: 1.39885
# [450]	training's rmse: 1.15573	valid_1's rmse: 1.36232
# [600]	training's rmse: 1.09136	valid_1's rmse: 1.34685
# [750]	training's rmse: 1.04553	valid_1's rmse: 1.34006
# [900]	training's rmse: 1.00874	valid_1's rmse: 1.33716
# [1050]	training's rmse: 0.982927	valid_1's rmse: 1.33673
# [1200]	training's rmse: 0.959546	valid_1's rmse: 1.33656
# Early stopping, best iteration is:
# [1160]	training's rmse: 0.965759	valid_1's rmse: 1.33632
# Model training done in 22.26206064224243 seconds.
# Fold error 1.336315642923176
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.43208	valid_1's rmse: 1.39001
# [300]	training's rmse: 1.28094	valid_1's rmse: 1.28456
# [450]	training's rmse: 1.19775	valid_1's rmse: 1.24721
# [600]	training's rmse: 1.14073	valid_1's rmse: 1.23322
# [750]	training's rmse: 1.1025	valid_1's rmse: 1.2285
# [900]	training's rmse: 1.0721	valid_1's rmse: 1.22783
# Early stopping, best iteration is:
# [866]	training's rmse: 1.0784	valid_1's rmse: 1.22736
# Model training done in 26.873878002166748 seconds.
# Fold error 1.2273603092237235
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42493	valid_1's rmse: 1.45797
# [300]	training's rmse: 1.27232	valid_1's rmse: 1.36446
# [450]	training's rmse: 1.18966	valid_1's rmse: 1.33307
# [600]	training's rmse: 1.13215	valid_1's rmse: 1.31997
# [750]	training's rmse: 1.0935	valid_1's rmse: 1.31441
# [900]	training's rmse: 1.0628	valid_1's rmse: 1.31285
# [1050]	training's rmse: 1.04017	valid_1's rmse: 1.31315
# Early stopping, best iteration is:
# [960]	training's rmse: 1.05384	valid_1's rmse: 1.3121
# Model training done in 29.038577795028687 seconds.
# Fold error 1.3121036975715032
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41418	valid_1's rmse: 1.50552
# [300]	training's rmse: 1.2568	valid_1's rmse: 1.42469
# [450]	training's rmse: 1.17062	valid_1's rmse: 1.39488
# [600]	training's rmse: 1.11313	valid_1's rmse: 1.38298
# [750]	training's rmse: 1.07425	valid_1's rmse: 1.37769
# [900]	training's rmse: 1.04347	valid_1's rmse: 1.3753
# [1050]	training's rmse: 1.02009	valid_1's rmse: 1.37511
# Early stopping, best iteration is:
# [977]	training's rmse: 1.03168	valid_1's rmse: 1.37444
# Model training done in 27.9110369682312 seconds.
# Fold error 1.374440207760824
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40949	valid_1's rmse: 1.52678
# [300]	training's rmse: 1.25431	valid_1's rmse: 1.43293
# [450]	training's rmse: 1.16725	valid_1's rmse: 1.40061
# [600]	training's rmse: 1.10902	valid_1's rmse: 1.38879
# [750]	training's rmse: 1.06812	valid_1's rmse: 1.38461
# [900]	training's rmse: 1.03604	valid_1's rmse: 1.38268
# Early stopping, best iteration is:
# [895]	training's rmse: 1.03703	valid_1's rmse: 1.38266
# Model training done in 25.866407871246338 seconds.
# Fold error 1.382657309897073
# Total error 1.33848114226
# Total std 0.05583
# Fitting big fold 19 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40004	valid_1's rmse: 1.50784
# [300]	training's rmse: 1.23756	valid_1's rmse: 1.41448
# [450]	training's rmse: 1.14617	valid_1's rmse: 1.37956
# [600]	training's rmse: 1.08548	valid_1's rmse: 1.36506
# [750]	training's rmse: 1.0429	valid_1's rmse: 1.35968
# [900]	training's rmse: 1.01104	valid_1's rmse: 1.35774
# [1050]	training's rmse: 0.986977	valid_1's rmse: 1.35734
# Early stopping, best iteration is:
# [1035]	training's rmse: 0.989352	valid_1's rmse: 1.35712
# Model training done in 19.895790100097656 seconds.
# Fold error 1.3571226803449465
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42734	valid_1's rmse: 1.40967
# [300]	training's rmse: 1.27285	valid_1's rmse: 1.32951
# [450]	training's rmse: 1.18834	valid_1's rmse: 1.30634
# [600]	training's rmse: 1.13083	valid_1's rmse: 1.30041
# [750]	training's rmse: 1.09189	valid_1's rmse: 1.30023
# Early stopping, best iteration is:
# [672]	training's rmse: 1.11096	valid_1's rmse: 1.29949
# Model training done in 24.42198657989502 seconds.
# Fold error 1.2994943975363062
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42387	valid_1's rmse: 1.46917
# [300]	training's rmse: 1.27295	valid_1's rmse: 1.35937
# [450]	training's rmse: 1.19075	valid_1's rmse: 1.32056
# [600]	training's rmse: 1.13311	valid_1's rmse: 1.30255
# [750]	training's rmse: 1.0929	valid_1's rmse: 1.29539
# [900]	training's rmse: 1.06269	valid_1's rmse: 1.29196
# [1050]	training's rmse: 1.03897	valid_1's rmse: 1.2895
# Early stopping, best iteration is:
# [1097]	training's rmse: 1.03236	valid_1's rmse: 1.28907
# Model training done in 30.070115327835083 seconds.
# Fold error 1.2890700697389683
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42173	valid_1's rmse: 1.47033
# [300]	training's rmse: 1.2666	valid_1's rmse: 1.37325
# [450]	training's rmse: 1.18189	valid_1's rmse: 1.34065
# [600]	training's rmse: 1.12475	valid_1's rmse: 1.32759
# [750]	training's rmse: 1.08469	valid_1's rmse: 1.32405
# [900]	training's rmse: 1.05253	valid_1's rmse: 1.32381
# Early stopping, best iteration is:
# [817]	training's rmse: 1.06953	valid_1's rmse: 1.32342
# Model training done in 25.606372356414795 seconds.
# Fold error 1.323416818014148
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.4142	valid_1's rmse: 1.50828
# [300]	training's rmse: 1.258	valid_1's rmse: 1.41758
# [450]	training's rmse: 1.17252	valid_1's rmse: 1.38358
# [600]	training's rmse: 1.11434	valid_1's rmse: 1.37027
# [750]	training's rmse: 1.0743	valid_1's rmse: 1.36604
# [900]	training's rmse: 1.04408	valid_1's rmse: 1.36464
# Early stopping, best iteration is:
# [896]	training's rmse: 1.04497	valid_1's rmse: 1.36453
# Model training done in 24.884210109710693 seconds.
# Fold error 1.3645349159406401
# Total error 1.33856323869
# Total std 0.03008
# Fitting big fold 20 out of 20
# Fitting sub fold 1 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42251	valid_1's rmse: 1.47819
# [300]	training's rmse: 1.26062	valid_1's rmse: 1.38107
# [450]	training's rmse: 1.1714	valid_1's rmse: 1.34589
# [600]	training's rmse: 1.10825	valid_1's rmse: 1.33116
# [750]	training's rmse: 1.06599	valid_1's rmse: 1.32539
# [900]	training's rmse: 1.03282	valid_1's rmse: 1.32345
# [1050]	training's rmse: 1.0079	valid_1's rmse: 1.32313
# [1200]	training's rmse: 0.985419	valid_1's rmse: 1.32295
# Early stopping, best iteration is:
# [1118]	training's rmse: 0.997318	valid_1's rmse: 1.32267
# Model training done in 20.43299174308777 seconds.
# Fold error 1.3226732193242814
# Fitting sub fold 2 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.41891	valid_1's rmse: 1.50566
# [300]	training's rmse: 1.26583	valid_1's rmse: 1.4073
# [450]	training's rmse: 1.18318	valid_1's rmse: 1.37305
# [600]	training's rmse: 1.12616	valid_1's rmse: 1.36001
# [750]	training's rmse: 1.08817	valid_1's rmse: 1.35532
# [900]	training's rmse: 1.05785	valid_1's rmse: 1.35334
# [1050]	training's rmse: 1.03445	valid_1's rmse: 1.35236
# [1200]	training's rmse: 1.01555	valid_1's rmse: 1.35187
# [1350]	training's rmse: 0.999232	valid_1's rmse: 1.35142
# Early stopping, best iteration is:
# [1295]	training's rmse: 1.00524	valid_1's rmse: 1.35122
# Model training done in 35.1328604221344 seconds.
# Fold error 1.3512156756150637
# Fitting sub fold 3 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42163	valid_1's rmse: 1.47681
# [300]	training's rmse: 1.26785	valid_1's rmse: 1.39078
# [450]	training's rmse: 1.18428	valid_1's rmse: 1.36049
# [600]	training's rmse: 1.12792	valid_1's rmse: 1.34821
# [750]	training's rmse: 1.08896	valid_1's rmse: 1.34501
# [900]	training's rmse: 1.05861	valid_1's rmse: 1.34526
# Early stopping, best iteration is:
# [841]	training's rmse: 1.06938	valid_1's rmse: 1.34449
# Model training done in 31.283353805541992 seconds.
# Fold error 1.344487912998266
# Fitting sub fold 4 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.42143	valid_1's rmse: 1.4708
# [300]	training's rmse: 1.26636	valid_1's rmse: 1.37528
# [450]	training's rmse: 1.17969	valid_1's rmse: 1.34243
# [600]	training's rmse: 1.12085	valid_1's rmse: 1.33043
# [750]	training's rmse: 1.07888	valid_1's rmse: 1.32568
# [900]	training's rmse: 1.04633	valid_1's rmse: 1.32396
# Early stopping, best iteration is:
# [879]	training's rmse: 1.05083	valid_1's rmse: 1.32373
# Model training done in 27.24943518638611 seconds.
# Fold error 1.3237259314543364
# Fitting sub fold 5 out of 5
# Training until validation scores don't improve for 100 rounds.
# [150]	training's rmse: 1.40884	valid_1's rmse: 1.52254
# [300]	training's rmse: 1.25323	valid_1's rmse: 1.43347
# [450]	training's rmse: 1.16617	valid_1's rmse: 1.40052
# [600]	training's rmse: 1.10715	valid_1's rmse: 1.3878
# [750]	training's rmse: 1.06645	valid_1's rmse: 1.3841
# [900]	training's rmse: 1.03335	valid_1's rmse: 1.38401
# Early stopping, best iteration is:
# [818]	training's rmse: 1.0504	valid_1's rmse: 1.38345
# Model training done in 24.46509289741516 seconds.
# Fold error 1.3834527245045263
# Total error 1.34083548235
# Total std 0.02222
# Wall time: 1h 10min 32s

# %%
print('Avg error:', np.mean(fold_errors))
print('Avg std:', np.mean(fold_std))
# Out:
# Avg error: 1.34039566247
# Avg std: 0.027104

# %%
# ERRORS
# errors = pd.DataFrame(fold_errors)
# errors.to_csv(os.path.join(PATH_TO_DATA, 'output/20_fold_errors_lgb_cv1340_std0027.csv'), index=False, header=False)

# 20x TRAIN TARGET OOF PREDS
with open(os.path.join(PATH_TO_DATA, 'output/nikita_train_20_folds_lgb_cv1340_std0027.pkl'), 'wb') as f:
    pickle.dump(y_oof_lgb, f)

# 20x TEST PREDS
with open(os.path.join(PATH_TO_DATA, 'output/nikita_test_20_folds_lgb_cv1340_std0027.pkl'), 'wb') as f:
    pickle.dump(pred_test_list_lgb, f)
